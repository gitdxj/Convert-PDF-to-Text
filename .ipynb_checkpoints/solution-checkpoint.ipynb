# %% [markdown]
# pdfminer3k
# pdfminer.six
# pypdf
# pypdfocr

# %%
phone_numbers = ["./data/phone_numbers/070219_KV_BR_Telefonverzei.pdf",
                "./data/phone_numbers/52_pdf_wegweiser_schlaganfall.pdf",
                 "./data/phone_numbers/FL_SYB_BetriebsaerztlicherDienst_ID8414.pdf",
                 "./data/phone_numbers/Infoblatt_154.pdf"
                ]
scans = ["./data/scans/double_ocr.pdf",
         "./data/scans/single_ocr.pdf"]

# %% [markdown]
# ### pdfminer

# %%
#!/usr/bin/env python3
#-*- coding:utf-8 -*-
# pip3 install pdfminer3k
  
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LAParams, LTTextBoxHorizontal
from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter, PDFTextExtractionNotAllowed
from pdfminer.pdfdevice import PDFDevice
 
def read_pdf(pdf_name, result_name):
    # 以二进制读模式打开
    fp = open(pdf_name, 'rb')
    # 用文件对象来创建一个pdf文档分析器
    parser = PDFParser(fp)
    # 创建一个pdf文档
    doc = PDFDocument()
    # 连接分析器 与文档对象
    parser.set_document(doc)
    doc.set_parser(parser)
    # 提供初始密码，如果没有密码 就创建一个空的字符串
    doc.initialize('')
    # 检测文档是否提供txt转换，不提供就抛出异常
    if not doc.is_extractable:
        raise PDFTextExtractionNotAllowed
    # 创建PDf 资源管理器 来管理共享资源
    rsrcmgr = PDFResourceManager()
    # 创建一个PDF设备对象
    laparams = LAParams()
    device = PDFPageAggregator(rsrcmgr, laparams=laparams)
    # 创建一个PDF解释器对象
    interpreter = PDFPageInterpreter(rsrcmgr, device)
     
    with open(result_name,"w",encoding="utf-8") as fd_out:
        # 循环遍历列表，每次处理一个page的内容
        for i,page in enumerate(doc.get_pages(),1):
            index = "===========《第{}页》===========".format(i)
            print(index)
            fd_out.write(index + "\n")
            interpreter.process_page(page)
            # 接受该页面的LTPage对象
            layout = device.get_result()
            for x in layout:
                if hasattr(x,"get_text"):
                    results = x.get_text()
                    print(results)
                    fd_out.write(results) 
                # 这里layout是一个LTPage对象 里面存放着 这个page解析出的各种对象 一般包括LTTextBox,
                # LTFigure, LTImage, LTTextBoxHorizontal 等等 想要获取文本就获得对象的text属性
                #if not isinstance(x, LTTextBoxHorizontal):
                #    continue
                #results = x.get_text()
                #print(results)
                #fd_out.write(results)   
 
                         
 

pdf_name = './data/phone_numbers/070219_KV_BR_Telefonverzei.pdf'
result = './test.txt'
read_pdf(pdf_name, result)
# Out:
# WARNING:root:Literal required: CIDSystemInfo
# WARNING:root:Literal required: CIDSystemInfo
# ===========《第1页》===========
# UniversitätsKlinikum Heidelberg
#
# TelefonBuch
#
# So können Sie uns erreichen!
#
# Klinik für Kinder- und Jugendmedizin
#
# · Not fallambulanzen
# · Ambulanzen
# · Stationäre Aufnahme
#
# Stand Januar 2007
# www.klinikum.uni-heidelberg.de
#
# ===========《第2页》===========
# Abteilung K inderheilkunde I
#
# Schwerpunk t Allgemeine Pädiatr ie · Stof f wechsel ·
# X X X X X X X X
#
# Inhaltsverzeichnis
#
# Telefonbuch Universitätsklinikum Heidelberg
#
# Telefonzentrale und Notfallambulanzen
#
# Anästhesiologische Klinik
#
# Augenklinik
#
# Chirurgische Klinik
# Klinik für Allgemein-, Viszeral- , Unfall-  und Kinderchirurgie
# K linik für Her zchirurgie
# K linik für Gefäßchirurgie
# K linik für Urologie
#
#   6
#
#   8
#
#  10
#
#  14
#
# Frauenklinik
# Allgemeine Frauenheilkunde und Gebur tshilfe
# Gynäkologische Endokr inologie und Fer tilitätsstörungen
#
#  26
#
# Klinik für Hals-, Nasen-, Ohrenheilkunde
#
# Hautklinik
#
# Heidelberger Ionenstrahl-Therapiezentrum (HIT )
#
#  32
#
#  36
#
#  40
#
#  42
#
# Klinik für Kinder- und Jugendmedizin
# K inderheilkunde I
# Allgemeine Pädiatrie, Stof fwechsel-Gastroenterologie-Nephrologie
# K inderheilkunde II
# K inderkardiologie
# K inderheilkunde III
# Onkologie, Hämatologie, Immunologie und Pneumologie
# K inderheilkunde IV
# Neonatologie
# K inderheilkunde V
# Kinderneurologie und Sozialpädiatrisches Zentrum, Epilepsiezentrum
#
#
#
# Impressum
#
# Herausgeber
# Universitätsklinikum Heidelberg
#
# Auf traggeber
# K linikumsvorstand
#
# Gestaltung und Satz
# Medienzentrum
# www.medienzentrum.klinikum.uni-heidelberg.de
#
# Redaktion
# Stabsstelle für Presse - und Öf fentlichkeitsarbeit
# www.presse.klinikum.uni-heidelberg.de
#
# Druck
# Nino Druck GmbH, Neustadt/ Weinstraße
#
#
#
#
#
#
#
# ===========《第3页》===========
# Abteilung K inderheilkunde I
# Inhaltsverzeichnis
#
# Schwerpunk t Allgemeine Pädiatr ie · Stof f wechsel ·
# Telefonbuch Universitätsklinikum Heidelberg
# X X X X X X X X
#
#  56
#
# Medizinische Klinik
# Innere Medizin I und K linische Chemie
# Endokr inologie und Stof fwechsel
# Innere Medizin II
# Psychosomatische und allg. klinische Medizin
# Innere Medizin III
# Kardiologie, Angiologie und Pneumologie
# Innere Medizin IV
# Gastroenterologie, Infek tionskrankheiten, Vergif tungen
# Innere Medizin V Hämatologie, Onkologie, Rheumatologie
# Innere Medizin VII Spor tmedizin
#
# Mund-, Zahn-, Kieferklinik
# Poliklinik für K ieferor thopädie
# Poliklinik für Zahnerhaltungskunde
# Poliklinik für Zahnär ztliche Prothetik
# K linik und Poliklinik für Mund-, K iefer- u. Gesichtschirurgie
#
#  72
#
# Nationales Centrum für Tumorerkrankungen (NCT )
#
# Neurochirurgische Klinik
#
# Neurologische Klinik
# Neurologie
# Neuroradiologie
# Neuroonkologie
#
#  80
#
#  82
#
#  84
#
# Zentrum für Psychosoziale Medizin
# K linik für Allgemeine Psychiatr ie
# Psychsomatische und allgemeine klinische Medizin
# K linik für K inder und Jugendpsychiatr ie
# Institut für Medizinische Psychologie
# Institut für Psychosomatische Kooperationsforschung und
# Familientherapie
#
#  92
#
#
#
# Radiologische Klinik
# Radioonkologie und Strahlentherapie
# Radiodiagnostik
# Nuklearmedizin
# Pädiatr ische Radiologie
#
# Institut für Humangenetik
#
# 106
#
# 114
#
# Hygiene -Institut
# Abteilung Hygiene u. Medizinische Mikrobiologie
# Abteilung Parasitologie
# Abteilung V irologie
# Abteilung Tropenhygiene u. öf fentliches Gesundheitswesen
#
# 116
#
# Institut für Immunologie
# Abteilung Allgem. Immunologie, Serologie,
# Hämatologische Diagnostik mit Blutbank
# Abteilung Transplantationsimmunologie
#
# Pathologisches Institut
#
# Zentrallabor
#
# Sozialdienst
#
# Weitere Ansprechpar tner
# Allgemeinmedizin und Versorgungsforschung
# (HeiCuMed/Lehrpraxen)
# Qualitätsmagement/Medizincontrolling
# Medizinische Kooperationen/
# Zusammenarbeit mit niedergelassenen Är zten
#
# Pläne und Wege
#
# 120
#
# 122
#
# 124
#
# 126
#
# 130
#
# 132
#
#
#
#
#
# ===========《第4页》===========
# Telefonzentrale und Not fallambulanzen
#
# Bereiche
#
# Telefonzentrale
#
# Notfallrufnummern 24 Std. erreichbar
#
# Chirurgische Klinik
# Not fallambulanz
#
# Medizinische Klinik
# Allgemeine Not fallambulanz
#
# Not fallambulanz Kardiologie (Chest-Pain-Unit)
#
# Augenheilkunde, HNO, Mund-, Zahn-, Kieferklinik ,
# Neurologie und Neurochirurgie
#
# Not fallambulanz
#
# P for te
#
# Frauenklinik
# Not fälle / P for te
#
# Kreissaal
#
# Hautklinik
# Not fälle / P for te
#
# Klinik für Kinder- u. Jugendmedizin
# Allgemeine Not fallambulanz
#
# Klinik für allgemeine Psychatrie
#
#
#
# Telefon
#
# 06221 / 56 0
#
# 0221 /  220
#
# 0221 /  8781
# und
#  8782
# 0221 /  8080
#
# 0221 /  7211
#
# 0221 /  99
# und
#  999
#
# 0221 /  78
#
# 0221 /  7971
#
# 0221 /  7011
#
# 0221 /  219
#
# 0221 /  7
#
# 7
#
# ===========《第5页》===========
# Anästhesiologische K linik
#
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. E . Mar tin
#
# Zentrales Patientenmanagement
#
# Anästhesiesprechstunde
#
# Aufwachraum
#
# Interdisziplinäre, operative Intensivstation
#
# Schockraum
#
# Zeiten
#
# Mo – Do  10.00 – 1.00 Uhr
# Fr
# 10.00 – 1 .00 Uhr
#
# Telefon
#
# Sekretar iat
# 0221 /  1
#
# 0221 /  878
# und
#  880
#
# 0221 /  8888
#
# 0221 /  891
#
# 0221 /  891
#
# 0221 /  891
#
# Zentrum für Schmerztherapie und Palliativmedizin
# (Über regionales Schmer zzentrum Heidelberg – Mannheim)
#
# Patientenanmeldung
#
# 0221 /  2
#
# Mo – Do
# Fr
#
#  8.00 – 1.00 Uhr
#  8.00 – 1 .00 Uhr
#
# 8
#
# 9
#
#
#
#
#
# ===========《第6页》===========
# Augenklinik
#
# Bereiche
#
# Är ztlicher Direk tor:  Prof. Dr. H. E . Völcker
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  0
#
# Terminvereinbarung stationäre Aufnahmen / Operationen
#
# 0221 /
#
# Pr ivatsprechstunde Professor Völcker
#
# Allgemeine Sprechstunde
#
# Not fallambulanz / P for te der Kopf klinik
#
# Ambulantes Oper ieren
#
# Glaukomsprechstunde und HRT-Diagnostik
#
# Hornhautsprechstunde
#
# Katarak t und Linsensprechstunde
#
# Kontak tlinsensprechstunde
#
# Netzhautchirurgische Sprechstunde
#
# Sekretar iat
# 0221 /  0
#
# 0221 /  1
#
# 0221 /  2
#  99
# Außerhalb der Dienstzeiten
#  999
#
# 0221 /  2898
#
# 0221 /  1
#
# 0221 /  9
#
# 0221 /  9
#
# 0221 /  19
#
# 0221 /  1
#
# 10
#
# 11
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第7页》===========
# Augenklinik
#
# Bereiche
#
# Netzhaut- / Makulasprechstunde
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Telefon
#
# 0221 /  1
#
# Ophtalmologische Rehabilitation / vergrößernde Sehhilfen
#
# 0221 /  2
#
# Ref rak tive Sprechstunde
#
# Schielbehandlung und  Neurophtalmologie
#
# Uveitissprechstunde
#
# 0221 /  7
#
# 0221 /
#
# 0221 /  807
#
# 12
#
# 1
#
#
#
#
#
#
#
#
#
# ===========《第8页》===========
# Chirurgische K linik
#
# K linik für Allgemein-, V iszeral-, Unfall- und K inderchirurg ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. M . W. Büchler
#
# Terminvereinbarung stationäre Aufnahme
# (Zentrales Patientenmanagement)
#
# Pr ivatsprechstunde Professor Büchler
#
# Allgemeine Ambulanz
#
# Not fallambulanz
#
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Zeiten
#
# Di
# Do
#
#  8.0 – 11.00 Uhr
# 1 .0 – 1.00 Uhr
#
# Mo – Fr
#  8.0 – 11.00 Uhr
# Sa
#  9.00 – 12.00 Uhr
# So und Feier tag
# 10.00 – 12.00  Uhr
#
# Telefon
#
# Sekretar iat
# 0221 /  201
#
# 0221 /  878
# und
#  880
#
# Nur auf Anmeldung
# über das Sekretar iat
# 0221 /  202
#
# 0221 /  220
#
# 2 Std. er reichbar
# 0221 /  220
#
# Oberar zt-Sprechstunde
#
# 0221 /  21
#
# Mo, Mi, Fr   8.0 – 11.00  Uhr
#
# Gastroenterologische Ambulanz
#
# 0221 /  209
#
# Mo, Mi, Fr   8.00 – 11.00 Uhr
#
# Pankreas-Sprechstunde
#
# FAP-Sprechstunde
#
# HNPCC-Sprechstunde
#
# 1
#
# 0221 /  7807
# und
#  821
#
# Mo - Fr
#
# 1 .00 – 1 .00 Uhr
#
# 0221 /  209
#
# Di
#
#  8.00 – 12.00 Uhr
#
# 0221 /  209
#
# Do
#
#  8.00 – 12.00 Uhr
#
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第9页》===========
# Chirurgische K linik
#
# K linik für Allgemein-, V iszeral-, Unfall- und K inderchirurg ie
#
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Bereiche
#
# Schilddrüsensprechstunde
#
# Telefon
#
# Zeiten
#
# 0221 /  217
#
# Mi
#
# 1 .00 – 1 .00 Uhr
#
# Sprechstunde Chirurgische Onkologie
#
# 0221 /  22
#
# Mo - Do
#
#  8.00 – 12.00 Uhr
#
# Handchirurgische Sprechstunde
#
# 0221 /  22
#
# Mo, Mi, Fr   8.0 – 11.00 Uhr
#
# Gelenksonographie
#
# 0221 /  220
#
# Mo ab
#
# 1 .00 Uhr
#
# Endoskopie, Prok tologie, Manometr ie
#
# Anästhesiesprechstunde
#
# Transplantationszentrum
#
# Nieren- / Pankreastransplantation
#
# Sprechstunde Leber transplantation
#
# Transplantationskoordination
#
# Sektion Unfallchirurgie
#
# Leiter: Pr ivatdozent Dr. Müller-Mai
#
# 0221 /  22
#
# 0221 /  8888
#
# Mo – Do 10.00 – 1.00 Uhr
# Fr
# 10.00 – 1 .00 Uhr
#
# 0221 /  2
#
# Mo – Fr
#
#  8.00 – 1 .0 Uhr
#
# 0221 /  8
# und
#  292
#
# Mi und Do   8.0 – 1.00 Uhr
#
# 0221 /  7 und
# 010 / 90 8 0 72
#
# Sekretar iat
# 0221 /  22
#
# Unfallchirurgische Sprechstunde
#
# 0221 /  22
#
# Mo - Fr
#
#  9.00 – 12.00  Uhr
#
# 1
#
# 17
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第10页》===========
# Chirurgische K linik
#
# K linik für Allgemein-, V iszeral-, Unfall- und K inderchirurg ie
#
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Bereiche
#
# Sektion Kinderchirurgie
#
# Sek tionsleitung:  Dr. S. Holland-Cunz
#
# Terminvereinbarung stationäre Aufnahme
# (Zentrales Patientenmanagement)
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  281
# 011 / 1708217
#
# 0221 /  980
#
# Pr ivatsprechstunde  Dr. Holland-Cunz
#
# 0221 /  282
#
# nach Vereinbarung
#
# Allgemeine Ambulanz
#
# 0221 /  220
#
# Mo – Fr
#  8.0 – 11.00  Uhr
# Sa
#  9.00 – 12.00  Uhr
# So und Feier tag
# 10.00 – 12.00 Uhr
#
# Not fallambulanz
#
# 2 Std. er reichbar
# 0221 /  220
#
# Allgemeine Sprechstunde
#
# 0221 /  282
#
# Mo – Do 1 .0 – 1 . Uhr
#
# Hämangiomsprechstunde
#
# 0221 /  28
#
# Do
#
# 1 .0 – 1.00 Uhr
#
# 18
#
# 19
#
#
#
#
#
# ===========《第11页》===========
# Chirurgische K linik
#
# K linik für Her zchirurg ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. M . Karck
#
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  272
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# Terminvereinbarung stationäre Aufnahme
#
# 0221 /  272
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# Pr ivatsprechstunde Professor Karck
#
# 0221 /  272
#
# nach Vereinbarung
#
# Allgemeine Ambulanz
#
# Not fallambulanz
#
# Mo – Fr
#
# 1 .00 – 1 .0 Uhr
#
# Stationssekretar iat
# 0221 /  27
#
# 2 Std. er reichbar
# 0221 /  110
#
# 20
#
# 21
#
#
#
# ===========《第12页》===========
# Chirurgische K linik
#
# K linik für Gefäßchirurg ie
#
# Bereiche
#
# Kom. Är ztlicher Direk tor: Prof. Dr.  J.-R . Allenberg
#
# Terminvereinbarung stationäre Aufnahme
#
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  29
#
# 0221 /  910
#
# Pr ivatsprechstunde Professor Allenberg
#
# 0221 /  29
#
# Di
#
#  9.00 – 1 .00 Uhr
#
# Allgemeine Ambulanz
#
# 0221 /  220
#
# Mo – Fr
#  8.0 – 11.00 Uhr
# Sa
#  9.00 – 12.00 Uhr
# So und Feier tag
# 10.00 – 12.00 Uhr
#
# Not fallambulanz
#
# 2 Std. er reichbar
# 0221 /  220
#
# Allgemeine Sprechstunde Gefäße und Var izen
#
# 0221 /  22
#
# Mo
# Fr
#
#  9.00 – 1 .00 Uhr
#  9.00 – 1 .00  Uhr
#
# Prästationäre Sprechstunde
#
# 0221 /  22
#
# Di
#
# 10.00 – 12.00 Uhr
#
# Septische Gefäßsprechstunde
#
# 0221 /  22
#
# Di und Do 12.00 – 1 .0 Uhr
#
# Spezialsprechstunde Carotis
#
# 0221 /  22
#
# Mi
#
#  9.00 – 1 .00 Uhr
#
# Spezialsprechstunde Aor ta
#
# 0221 /  22
#
# Do
#
#  9.00 – 1 .00 Uhr
#
# 22
#
# 2
#
#
#
#
#
# ===========《第13页》===========
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Chirurgische K linik
#
# K linik für Urolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. M . Hohenfellner
#
# Terminvereinbarung stationäre Aufnahme
#
# Pr ivatsprechstunde Professor Hohenfellner
#
# Urologische Ambulanz
#
# Hotline -Urologie
#
# Telefon
#
# Sekretar iat
# 0221 /  21
#
# 0221 /  701
# und
#  70
#
# 0221 /  21
#
# 0221 /  27
# und
#  28
#
# 0221 /  98
#
# 2
#
# 2
#
#
#
# ===========《第14页》===========
# Frauenklinik
#
# Allgemeine Frauenheilkunde und Gebur tshilfe
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. C . Sohn
#
# Terminvergabe stationäre Aufnahme
# (Zentrales Patientenmanagement)
#
# Pr ivatambulanz Professor Sohn
#
# P for te der Frauenklinik (Not fälle)
#
# Allgemeine Ambulanz
#
# Schwangerenambulanz
#
# Kreissaal
#
# Voßstr. 9 · 911 Heidelberg
#
# Zeiten
#
# Telefon
#
# Sekretar iat
# 0221 /  7901
#
# 0221 /  798
#
# 0221 /  7901
#
# 2 Std. er reichbar
# 0221 /  78
#
# 0221 /  79
#
# 0221 /  79
#
# 0221 /  7971
#
# Elternberatungszentrum
#
# 0221 /  898
#
# Mo - Do
#
#  9.00 – 11.00 Uhr
#
# Ultraschall
#
# Onkologische Ambulanz
#
# Brustsprechstunde
#
# Urog ynäkologische Sprechstunde
#
# 2
#
# 0221 /  79
#
# 0221 /  798
#
# 0221 /  788
#
# 0221 /  79
#
# Di
# Mi
#
#  12.0 – 1.00 Uhr
#  12.0 – 1.00 Uhr
#
# 27
#
#
#
# ===========《第15页》===========
# Frauenklinik
#
# Allgemeine Frauenheilkunde und Gebur tshilfe
#
# Voßstr. 9 · 911 Heidelberg
#
# Bereiche
#
# Dysplasiesprechstunde
#
# Terminvereinbarung
# Operationstermine
#
# Telefon
#
# Zeiten
#
# Mo, Di, Do ab
#
# 1 .00 Uhr
#
# 0221 /  79
# 0221 /  798
#
# Ästhetische und rekonstruk tive Mammachirurgie
#
# 0221 /  792
#
# Hysteroskopiesprechstunde
#
# 0221 /  79
#
# K inder- und Jugendg ynäkologie
#
# 0221 /  79
#
# Mo
#
# 12.00 – 1 .00 Uhr
#
# 28
#
# 29
#
#
#
#
#
#
#
#
#
# ===========《第16页》===========
# Frauenklinik
#
# Gynäkolog ische Endokr inolog ie und Fer tilitätsstörungen
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. T. Strowitzki
#
# Pr ivatambulanz Professor Strowitzki
#
# Telefon
#
# Sekretar iat
# 0221 /  7910
#
# 0221 /  7910
#
# Voßstr. 9 · 911 Heidelberg
#
# Zeiten
#
# Mo, Do
# Di
#
# vormit tags
# nachmit tags
#
# K inder wunschambulanz
#
# 0221 /  7921
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# Hormonambulanz
#
# Naturheilkundeambulanz
#
# 0221 /  79
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# 0221 /  821
#
# Sprechstunden
# nach Vereinbarung
#
# Endometr iose -Sprechstunde
#
# 0221 /  79
#
# Do und Fr  8.00 – 1.00 Uhr
#
# Wiederholte Fehlgebur ten
#
# 0221 /  7921
#
# Mo
# Do
#
# 1 .00– 1.00  Uhr
# 1 .00 – 1.00  Uhr
#
# Fer tilitätserhalt bei Chemo - und Strahlentherapie
#
# 0221 /  7921
#
# nach Vereinbarung
#
# Fer tilitätsrelevante Chirurgie
#
# Genetisch beding te Fer tilitätsstörungen
#
# K inder- und Jugendsprechstunde
#
# 0221 /  7921
# und
#  79
#
# 0221 /  7918
#
# 0221 /  79
#
# Mo
#
# 1 .0 – 1.00 Uhr
#
# Fr
#
# Di
#
# 11.00 – 1 .00  Uhr
#
# 11.00 – 1 .00  Uhr
#
# 0
#
# 1
#
#
#
#
#
#
#
# ===========《第17页》===========
# K linik für Hals-, Nasen-Ohrenheilkunde
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. P. K . Plinker t
#
# Terminvereinbarung stationäre Aufnahme
#
# Pr ivatsprechstunde Professor Plinker t
#
# Telefon
#
# Sekretar iat
# 0221 /  701
#
# 0221 /  72
# und
#  71
#
# 0221 /  701
# und
#  709
#
# Zeiten
#
# Mi
# 10.00 – 19.00 Uhr
# Mo, Di, Do, Fr
#  9.00 – 1.00  Uhr
#
# Allgemeine HNO -Ambulanz
#
# 0221 /  72
#
# Mo – Fr
#
#  8.00 – 1 .00  Uhr
#
# Not fallambulanz der Kopf klinik
#
# Anmeldung für alle Sprechstunden
# Ambulanzleitstelle
#
# Allergiesprechstunde
#
# K indersprechstunde
#
# HNO - NCT- Sprechstunde
#
# HNO - Tumorboard im NCT
#
# HNO - Radiologische interdisziplinäre Sprechstunde
#
# Lar yngologische Sprechstunde
#
# 2
#
# 0221 /  999
#
# 06221 / 56 6752
#
# Do
#
# 1 .00 – 1 .00 Uhr
#
# Di
#
#  9.00 – 12.00  Uhr
#
# Mi
#
#  8.0 – 1 .00  Uhr
#
# Mi
#
# 1 .00 – 1 .00 Uhr
#
# Mi
#
#  8.0 – 1 .00  Uhr
#
# Fr
#
#  9.00 – 1 .00  Uhr
#
#
#
#
#
#
#
#
#
#
#
# ===========《第18页》===========
# K linik für Hals-, Nasen-Ohrenheilkunde
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Bereiche
#
# Otologische Sprechstunde
#
# Telefon
#
# Zeiten
#
# Mo
#
#  9.00 – 1 .00  Uhr
#
# Sprechstunde für plastische und ästhetische Operationen
#
# Mi
#
#  8.00 – 1 .00  Uhr
#
# Schädelbasis- und Dysphagiesprechstunde
#
# Tauchersprechstunde
#
# Tumorsprechstunde
#
# Mi
#
# 12.00 – 1.00 Uhr
#
# Do
#
# 12.00 – 1 .00  Uhr
#
# 0221 /  728
#
# Mi
#
#  8.00 – 1 .00  Uhr
#
# Phoniatr ie und Pädaudiologie
#
# Mo – Fr
#
#  8.00 – 1 .00  Uhr
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第19页》===========
# Hautklinik
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. A . Enk
#
# Terminvereinbarung stationäre Aufnahme
# (Zentrales Patientenmanagement)
#
# Voßstr. 2 · 911 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  801
#
# Zeiten
#
# 0221 /  890
#
# Mo – Fr
#
# 12.0 – 1 .00  Uhr
#
# Pr ivatsprechstunde Professor Enk
#
# 0221 /  801
#
# Mo – Fr
# Mo
#
#   9.0 – 12.00  Uhr
# 1.00 – 17.00  Uhr
#
# Allgemeine Ambulanz
# Ambulanzsekretar iat
#
# Patientenannahme
#
# Erst vorstellung
#
# P for te der Hautklinik (Not fälle)
#
# Allergieambulanz
# Ar zt termine
#
# Hyposensibilisierung
#
# Test termine
#
# 0221 /  10
#
# Mo – Do
# Fr
#
#  7.0 – 1.00  Uhr
#  7.0 – 1 .00  Uhr
#
# Mo, Di, Do, Fr
#  8.00 – 11.00  Uhr
#
# 0221 /  10
#
# Mi ( Terminsprechstunde)
#
# 2 Std. er reichbar
# 0221 /  7011
#
# 0221 /  8
#
# Mo – Fr
#  8.00 – 12.00  Uhr
# Mo, Di, Do 1 .00 – 1.00  Uhr
#
# Mo – Fr
#  8.00 – 12.00 Uhr
# Mo, Di, Do 1 .00 – 1.00  Uhr
#
# 0221 /  8
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# Andrologische Ambulanz
#
# 0221 /  901
#
# Mo und Do 9.00  – 10.00 Uhr
#
#
#
# 7
#
#
#
#
#
#
#
#
#
# ===========《第20页》===========
# Hautklinik
#
# Bereiche
#
# Ästhetische Ambulanz
#
# Immunologische Ambulanz
#
# Laser zentrum
#
# Onkologische Ambulanz
#
# Voßstr. 2 · 911 Heidelberg
#
# Telefon
#
# Zeiten
#
# 0221 /  79
#
# 0221 /  8
#
# Pr ivatpatienten
# 0221 /  79
#
# Kassenpatienten
# 0221 /  10
#
# 0221 /  87
#
# Mo – Do
# und
# Fr
#
#  8.00 – 11.0  Uhr
# 1 .00 – 1 .00  Uhr
# 10.00 – 12.0 Uhr
#
# Mo
#
#  8. – 10.0 Uhr
#
# Di
# 1 .0 – 1.00 Uhr
# Do und Fr   9.0 – 12.00  Uhr
#
# Mo – Do
# und
# Fr
#
#  9.0 – 12.0  Uhr
# 1 .0 – 1.00  Uhr
#  9.0 – 12.0  Uhr
#
# Ambulanz für Haut tumoren
# des Nationalen Centrums für Tumorerkrankungen (NCT )
#
# 0221 /  801
#
# Di
#
# 1 .00 – 1.00 Uhr
#
# Phlebologische Ambulanz
#
# Pr ivatpatienten
# 0221 /  79
#
# Kassenpatienten
# 0221 /  81
# und
#  887
#
# Mo
# Di
# Mi
# Do
#
# Mo
# und
# Di
# Mi
# und
# Do
#
# 1 .00 – 1 .00 Uhr
# 1 .00 – 1.00 Uhr
# 1.00 – 17.00 Uhr
# 10.00 – 12.0 Uhr
#
#  9.0 – 12.00  Uhr
# 1 .0 – 1.00  Uhr
#  9.0 – 12.00  Uhr
#  9.0 – 12.00  Uhr
# 1 .0 – 1.00  Uhr
# 1 .0 – 1.00  Uhr
#
# 8
#
# 9
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第21页》===========
# Heidelberger Ionenstrahl-Therapiezentrum (HIT )
#
# Protonen- und Schwer ionentherapie
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Behandlungsbeginn geplant ab Ende 2007
#
# Är ztlicher Direk tor: Prof. Dr. Dr. J. Debus
#
# Sekretar iat
# 0221 /  8201
# und
#  8202
#
# Allgemeine Ambulanz
#
# 0221 /  711
#
# Mo – Fr
#
# 8.00 - 1.00 Uhr
#
# Schwer ionentherapie
# Der zeit in Zusammenarbeit mit der GSI, Darmstadt
#
# 0221 /  711
#
# Mo
# Di
#
# vormit tags
# nachmit tags
#
# 0
#
# 1
#
#
#
#
#
#
#
# ===========《第22页》===========
# K linik für K inder- und Jugendmedizin
#
# K inderheilkunde I
# Allgemeine Pädiatr ie, Stof f wechsel - Gastroenterolog ie - Nephrolog ie
#
# Im Neuenheimer Feld 1 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Är ztlicher Direk tor: Prof. Dr. med. Prof. h.c. (RCH) G. F. Hof fmann
#
# Terminvereinbarung für stationäre Aufnahme
#
# Sekretar iat
# 0221 /  200
#
# 0221 /  219
#
# Pr ivatambulanz Professor Hof fmann
#
# 0221 /  219
#
# Mo, Mi, Do  9.00 – 10.00  Uhr
#
# Allgemeinambulanz
# (zentrale Terminvereinbarung für alle Ambulanzen der Abteilung I)
#
# 0221 /  219
#
# Mo – Fr
#
#  8.00 – 1 .00  Uhr
#
# Allgemeine Not fallambulanz
#
# Bestellambulanz
#
# Diabetesambulanz
#
# Endokr inologische Ambulanz
#
# Gastroenterologische Ambulanz
#
# 0221 /  219
#
# 0221 /  219
#
# Mo – Fr
#
#  8.0 – 11.0  Uhr
#
# 0221 /  219
# und
#  892
#
# Di
# Mi
#
# 1 .00 – 18.00 Uhr
# 1 .00 – 1.00 Uhr
#
# 0221 /  27
# und
#  219
#
# Pr ivatambulanz
# 0221 /  871
#
# 0221 /  219
#
# Di - Do
#  8.00 – 1 .00  Uhr
# und
# 1 .00 – 1.00 Uhr
# Mo – Fr     nach Vereinbarung
#
# Di und Do   9.00 – 12.00  Uhr
# Fr
#  8.00 – 10.00  Uhr
#
# Nierenambulanz
#
# 0221 /  222
#
# Mo – Fr
#
#  8.00 – 12.00  Uhr
#
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第23页》===========
# K linik für K inder- und Jugendmedizin
#
# K inderheilkunde I
# Allgemeine Pädiatr ie, Stof f wechsel - Gastroenterolog ie - Nephrolog ie
#
# Im Neuenheimer Feld 1 · 9120 Heidelberg
#
# Bereiche
#
# Dialyse
#
# Stof fwechselambulanz
#
# Telefon
#
# Zeiten
#
# 0221 /  8
# 2 Std.-Rufbereitschaf t
# 0221 /  211
#
# 0221 /  219
# 2 Std.-Rufbereitschaf t
# 0221 /  211
#
# Mi und Do  8.00 – 12.00  Uhr
#
# Neugeborenen-Screening
#
# 0221 /  8278
#
#
#
#
#
#
#
#
#
#
#
# ===========《第24页》===========
# K linik für K inder- und Jugendmedizin
#
# Im Neuenheimer Feld 1 · 9120 Heidelberg
#
# K inderheilkunde II
# K inderkardiolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. H. E . Ulmer
#
# Terminvereinbarung für stationäre Aufnahme
#
# Terminvereinbarung Intensivstation
#
# Allgemeine Not fallambulanz
#
# Pr ivatsprechstunde Professor Ulmer
#
# K inderkardiologische Ambulanz
#
# Her zschr it tmacherambulanz
#
# Her ztransplantationsambulanz
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  28
#
# 0221 /  22
#
# 0221 /  27
#
# 2-Std. er reichbar
# 0221 /  219
#
# 0221 /  28
#
# 0221 /  22
#
# 0221 /  22
#
# 0221 /  22
#
# Mo – Do
#  8.00 – 1 .00  Uhr
# Fr
#  8.00 – 1 .00  Uhr
# (Not fälle jeder zeit)
#
#
#
# 7
#
#
#
#
#
# ===========《第25页》===========
# K linik für K inder- und Jugendmedizin
#
# K inderheilkunde III
# Onkolog ie, Hämatolog ie, Immunolog ie und Pneumolog ie
#
# Im Neuenheimer Feld 1 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Är ztlicher Direk tor: Prof. Dr. A . Kulozik , PhD
#
# Pr ivatambulanz
# Prof. Dr. A . Kulozik
# PD Dr. F.- M . Müller
# PD Dr. O. Sommerburg
#
# Allgemeine Not fallambulanz
#
# Sekretar iat
# 0221 /
#
# 0221 /
#  8
#  219
#
# 2 Std. er reichbar
# 0221 /  211
# und
#  219
#
# Mo
# Do
#
# 1 .00 – 17.00  Uhr
#  9.00 – 12.00  Uhr
#
# Onkologische und hämatologische Ambulanz
#
# 0221 /  881
#
# Mo – Fr
#
#  8.0 – 1 .0  Uhr
#
# Pneumologische Sprechstunde
#
# 0221 /  219
#
# Allergie - u. Neurodermitis-Sprechstunde
#
# 0221 /  219
#
# Mo
# Di
#
# Mo
# Di
#
#  8.0 – 1.0 Uhr
#  9.00 – 11.00  Uhr
#
#  8.0 – 1.0 Uhr
#  9.00 – 1.0 Uhr
#
# Spezielle Infek tiologie
#
# 0221 /  219
#
# Di
#
#  9.00 – 11.0 Uhr
#
# CF-Ambulanz (Mukoviszidose)
#
# 0221 /  219
#
# Mo und Do 1 .00 – 1.0 Uhr
#
# 8
#
# 9
#
#
#
#
#
#
#
#
#
# ===========《第26页》===========
# K linik für K inder- und Jugendmedizin
#
# Im Neuenheimer Feld 1 · 9120 Heidelberg
#
# K inderheilkunde IV
# Neonatolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. O. Linderkamp
#
# Telefon
#
# Zeiten
#
# Sekretar iat (Frauenklinik)
# 0221 /  208
#
# Sekretar iat (K inderklinik)
# 0221 /  198
#
# Terminvereinbarung für stationäre Aufnahme
#
# 0221 /  198
#
# Mo – Fr
#
#  9.00 – 1 .00  Uhr
#
# Pr ivatambulanz Professor Linderkamp
#
# 0221 /  198
#
# Do
# Fr
#
# 11.00 – 1 .00  Uhr
#  9.00 – 1 .00  Uhr
#
# Ambulanz für kranke Neugeborene
#
# 0221 /  198
#
# Mo – Fr
#
# 1 .00 – 1.00 Uhr
#
# Not fallversorgung
# Oberär ztlicher Bereitschaf tsdienst
#
# Neugeborenen- Notar zt / Transpor tdienst
#
# 2 Std. er reichbar
# 0221 /  7977
#
# 0221 /  7977
# Außerhalb der Dienstzeiten
# 010 / 978017
#
# Monitorambulanz und Schlaf labor
#
# 0221 /  198
#
# Mo – Fr  nach Voranmeldung
#
# Frühgeborenen-Ambulanz
#
# 0221 /  198
# und
#  82
#
# Do und Fr  9.00 – 1 .00  Uhr
#
# 0
#
# 1
#
#
#
#
#
# ===========《第27页》===========
# K linik für K inder- und Jugendmedizin
#
# K inderheilkunde V
# K inderneurolog ie und Sozialpädiatr isches Zentrum, Epilepsiezentrum
#
# Im Neuenheimer Feld 1 · 9120 Heidelberg
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. D. Rating
#
# Terminvereinbarung stationäre Aufnahme
#
# Kinderneurologische Station
# Stationssekretar iat
# Akute Aufnahmen
#
# Allgemeine Not fallambulanz
#
# Prächirurgische Epilepsiediagnostik
#
# Pr ivatsprechstunde Professor Rating
#
# Anmeldung für alle Spezialambulanzen
#
# Sozialpädiatrisches Zentrum:
# Ambulanz für Entwicklungsstörungen und
# kinderneurologische Erkrankungen
#
# Epilepsie -Ambulanz (Schwerpunk t für therapieschwier ige
# Epilepsien und Epilepsiechirurgie)
#
# Ambulanz für neuromuskuläre Erkrankungen
#
# Ambulanz für chronische Kopfschmer zen und Migräne
#
# 2
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  888
#
# 0221 /  8
# 0221 /  791
#
# 2 Std. er reichbar
# 0221 /  211
# und
#  219
#
# 0221 /  8228
#
# 0221 /  27
#
# 06221 / 56 2337
#
# Mo, Mi, Do 8.00 – 17.00  Uhr
# Di
#  8.00 – 1.00  Uhr
# Fr
#  8.00 – 1 .00  Uhr
#
# Mo
# Mi
#
#  9.00 – 1 .00  Uhr
#  9.00 – 17.00  Uhr
#
# Do
#
# 1 .00 – 17.00  Uhr
#
# Do
#
# 1 .00 – 1.00  Uhr
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第28页》===========
# K linik für K inder- und Jugendmedizin
#
# K inderheilkunde V
# K inderneurolog ie und Sozialpädiatr isches Zentrum, Epilepsiezentrum
#
# Bereiche
#
# K inderor thopädisch-kinderneurologische Sprechstunde
#
# Ambulanz für K inder mit neurogenetischen Erkrankungen,
# Ataxien und Leukodystrophien
#
# Im Neuenheimer Feld 1 · 9120 Heidelberg
#
# Zeiten
#
# Nach Vereinbarung
#
# Mo
#
# 1 .00 – 1.00  Uhr
#
# K inderonkologisch-neurologische Hirntumorambulanz
#
# Mo
#
# 1 .00 – 17.00  Uhr
#
#
#
#
#
#
#
# ===========《第29页》===========
# Medizinische K linik
#
# Innere Medizin I  und K linische Chemie
# Endokr inolog ie und Stof f wechsel
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. P. Nawroth
#
# Pr ivatsprechstunde Professor Nawroth
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  801
#
# 0221 /  801
#
# Ambulanz für Endokr inologie, Stof fwechsel und Diabetologie
#
# 0221 /  8787
#
# Not fallambulanz
#
# Allgemeine Diabetesambulanz mit Spezialsprechstunden für
# Schwangere, Jugendliche und diabetische Fußprobleme
#
# Diabetesschulung
# (intensivier te Insulintherapie, Typ -2-Diabetes mit Insulin,
# Tablet ten- oder Ernährungstherapie, Insulinpumpentherapie,
# Schwangerschaf tsdiabetes)
#
# Adipositasambulanz
#
# Diät- und Ernährungsambulanz
# (Diät- und Ernährungsberatung bzw. -schulung von
# stationären und ambulanten Patienten)
#
# 2 Std. er reichbar
# 0221 /  8782
#
# 0221 /  8787
#
# 0221 /  87
#
# 0221 /  8787
#
# 0221 /  88
#
# Ambulanz für Fet tstof fwechselerkrankungen
#
# 0221 /  8787
#
#
#
# 7
#
#
#
# ===========《第30页》===========
# Medizinische K linik
#
# Innere Medizin II
# Psychosomatische und allgemeine klinische Medizin
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. W. Her zog
# Neue Medizinische K linik
#
# Altklinikum Bergheim
#
# Anmeldung für alle Ambulanzen
#
# Internistisch-Psychosomatische Ambulanz
# (Neue Medizinische K linik)
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  89
# Sekretar iat
# 0221 /  879
#
# 0221 /  877
#
# Mo – Do
# und
# Fr
#
#  8.00 – 12.00 Uhr
# 1 .00 – 1 .0 Uhr
#  8.00 – 12.0  Uhr
#
# Mo
# und
# Mi
# Do
#
#  9.00 – 12.00 Uhr
# 1 .00 – 1 .00  Uhr
# 11.00 – 1 .00 Uhr
#  8.0 – 11.0  Uhr
#
# Allgemein- internistische Ambulanz (Neue Medizinische K linik)
#
# Mo – Fr
#
#  8.00 – 12.00 Uhr
#
# Rheuma-/ Schmer zambulanz (Neue Medizinische K linik)
#
# Mo, Mi, Do 8.00 – 12.00 Uhr
#
# Psychosomatische Not fallversorgung
#
# Not fallambulanz
#
# 1.0 –   8.00  Uhr
#
# Dienstar zt
# 011 / 1792
# Oberar zt
# 011 / 11127
#
# 2 Std. er reichbar
# 0221 /  8781
# und
#  8782
#
# 8
#
# 9
#
#
#
#
#
#
#
#
#
# ===========《第31页》===========
# Medizinische K linik
#
# Innere Medizin III
# Kardiolog ie, Ang iolog ie und Pneumolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. H. A . Katus
#
# Terminvereinbarung stationäre Aufnahme
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  870
#
# Bet tenmanagement
# 0221 /  871
#
# Mo – Fr
#
#  8.00 – 19.00 Uhr
#
# Mo – Fr
#
#  7.0  – 1.00  Uhr
#
# Pr ivatsprechstunde Professor Katus
#
# 0221 /  872
#
# Mo – Fr
#
#  nach Vereinbarung
#
# Allgemeine Kardiologische Ambulanz
#
# Not fall-Ambulanz (Chest-Pain-Unit)
#
# Herzkatheter
#
# Mo – Fr
#
#  8.00 – 1.00  Uhr
#
# Leitstelle
# 0221 /  89
# Terminvereinbarung
# 0221 /  89
#
# 2 Std. er reichbar
# 0221 /  8080
#
# Leitstelle
# 0221 /  802
# Terminvereinbarung
# 0221 /  89
#
# Her zinsuf f izienz- und Transplantationsambulanz
#
# 0221 /  892
#
# Mo – Fr
#
#  8.00 – 17.00  Uhr
#
# Schr it tmacherambulanz/kardiale Resynchronisationstherapie
#
# 0221 /  89
# und
#  88
#
# Mo – Fr
#
#  8.00 – 17.00 Uhr
#
# Def ibr illator-Ambulanz
#
# 0221 /  88
#
# Mo – Fr
#
#  8.00 – 17.00 Uhr
#
# Inter ventionelle Elek trophysiologie
#
# 0221 /  88
#
# Mo – Fr
#
#  8.00 – 17.00 Uhr
#
# 0
#
# 1
#
# ===========《第32页》===========
# Medizinische K linik
#
# Innere Medizin III
# Kardiolog ie, Ang iolog ie und Pneumolog ie
#
# Bereiche
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Ambulanz für angeborene Her zrhy thmusstörungen
#
# 0221 /  88
#
# Mo – Fr
#
#  8.00 – 17.00 Uhr
#
# Synkopen-/Rhy thmussprechstunde
#
# 0221 /  88
#
# Mo – Fr
#
#  8.00 – 17.00 Uhr
#
# Angiologische Ambulanz
#
# 0221 /  89
#
# Mo – Fr
#
#  8.00 – 17.00 Uhr
#
# Pneumologische Ambulanz
#
# 0221 /  89
#
# Di, Mi, Do  8.00 – 17.00  Uhr
#
# Ambulantes Schlaf labor
#
# Ger innungsambulanz
#
# 0221 /  882
#
# nach Vereinbarung
#
# 0221 /  870
#
# Mi
#
# 10.00 – 12.00 Uhr
#
# Ar ter iosklerose Sprechstunde
#
# 0221 /  89
#
# Mo
#
#  8.00 – 1 .00  Uhr
#
# 2
#
#
#
#
#
# ===========《第33页》===========
# Medizinische K linik
#
# Innere Medizin IV
# Gastroenterolog ie, Infek tionskrankheiten, Verg if tungen
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. W. Stremmel
#
# Terminvereinbarung stationäre Aufnahme
# (Zentrales Patientenmanagement)
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  870
# persönlich
# 0221 /  8717
#
# 0221 /  870
#
# Pr ivatsprechstunde Professor Stremmel
#
# 0221 /  870
#
# Mo – Fr
#
# 11.00 – 1 .00  Uhr
#
# Leber transplantationsambulanz
#
# 0221 /  8
#
# Do
#
#  8.00 – 1 .00 Uhr
#
# Anmeldung für alle Ambulanzen
#
# 0221 /  8702
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# Onkologische Ambulanz
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# Ambulanz für chronisch entzündliche Darmerkrankungen
#
# Nach Vereinbarung
#
# Ambulanz für Hämochromatose
#
# Ambulanz für Morbus Wilson
#
# Not fallambulanz
#
# Är ztliche Anf ragen / Not fälle
#
#
#
# 2 Std. er reichbar
# 0221 /  8781
# und
#  8782
#
# 0221 /  999
#
# Do
#
#  8.00 – 12.00  Uhr
#
# Mi
#
#  8.00 – 12.00  Uhr
#
#
#
#
#
#
#
# ===========《第34页》===========
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  8000
# und
#  8001
#
# 0221 /  8098
# 2 Std. er reichbar
# 0221 /  80020
#
# 0221 /  8001
#
# Mo – Fr
#
#  8.00 – 18.00  Uhr
#
# Mo – Do
# Fr
#
#  7.0 – 19.00  Uhr
#  7.0 – 18.00  Uhr
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# Medizinische K linik
#
# Innere Medizin V
# Hämatolog ie, Onkolog ie, Rheumatolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. A . Ho
#
# Terminvereinbarung stationäre Aufnahme
#
# Pr ivatambulanz
# Professor Ho (Hämatologie/Onkologie)
# Professor Lorenz (Rheumatologie)
#
# Hämatologisch-onkologische Ambulanz
#
# 0221 /  800
#
# Rheuma-Ambulanz
#
# 0221 /  800
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# Allogene Transplantationsambulanz
#
# 0221 /  8009
#
# Autologe Transplantationsambulanz
#
# 0221 /  2781
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# Amyloidose -Ambulanz
#
# Not fallambulanz
#
#
#
# 0221 /  8009
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# 2 Std. er reichbar
# 0221 /  8781
# und
#  8782
#
# 7
#
#
#
#
#
#
#
# ===========《第35页》===========
# Medizinische K linik
#
# Innere Medizin V
# Hämatolog ie, Onkolog ie, Rheumatolog ie
#
# Bereiche
#
# Transplantationskoordination
#
# Psychologischer Dienst
#
# Spezialsprechstunde Myelom
#
# Spezialsprechstunde Lymphom
#
# Spezialsprechstunde Sarkom
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# 0221 /  819
#
# 0221 /  10
#
# Zeiten
#
# Mo – Do
# Fr
#
#  8.00 – 1.00  Uhr
#  8.00 – 1 .0  Uhr
#
# Mo – Do
# Fr
#
#  8.00 – 1.00  Uhr
#  8.00 – 1 .0  Uhr
#
# 0221 /  2781
# und
#  801 (NCT )
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# 0221 /  800,
#  8008
#  801 (NCT )
#
# und
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# 0221 /  8008
# und
#  801 (NCT )
#
# Mo – Do
# Fr
#
#  8.00 – 1 .0  Uhr
#  8.00 – 1 .00  Uhr
#
# 8
#
# 9
#
#
#
# ===========《第36页》===========
# Medizinische K linik
#
# Innere Medizin V II
# Spor tmedizin
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. P. Bär tsch
#
# Pr ivatsprechstunde Professor Bär tsch
#
# Allgemeine Spor tambulanz
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  8101
#
# 0221 /  8101
#
# 0221 /  821
#
# Zeiten
#
# Mo – Do
# Fr
#
#  8.00 – 1.00  Uhr
#  8.00 – 1 .00  Uhr
#
# Mo – Do
# Fr
#
#  8.00 – 1.00  Uhr
#  8.00 – 1 .00  Uhr
#
# Mo – Do
# Fr
#
#  8.00 – 1 .00 Uhr
#  8.00 – 12.00  Uhr
#
# 70
#
# 71
#
#
#
# ===========《第37页》===========
# Mund-, Zahn-, K ieferklinik
#
# Poliklinik für K ieferor thopädie
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Är ztliche Direk tor in: Prof. Dr. G. Komposch
#
# Leitstelle Ambulanz
#
# Beratung
#
# Sekretar iat
# 0221 /  1
#
# 0221 /
#
# Mo, Mi, Do 8.00 – 17.00  Uhr
# Di
#  8.00 – 17.0  Uhr
# Fr
#  8.00 – 1 .0  Uhr
#
# 0221 /
#
# Vormit tags,
# nach Vereinbarung
#
# Anmeldung für Spezialsprechstunden
#
# 0221 /
#
# Nach Vereinbarung
#
# Spaltsprechstunde
#
# Dysgnathiesprechstunde
#
# Sprechstunde für kraniofaziale Fehlbildungen
#
# 72
#
# 7
#
# ===========《第38页》===========
# Mund-, Zahn-, K ieferklinik
#
# Poliklinik für Zahnerhaltungskunde
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Är ztlicher Direk tor: Prof. Dr. Dr. H. J. Staehle
#
# Leitstelle Ambulanz
#
# Ambulanz
#
# Sekretar iat
# 0221 /  002
#
# 0221 /  011
#
# Mo, Mi, Do 8.00 – 17.00 Uhr
# Di
#  8.00 – 18.00 Uhr
# Fr
#  8.00 – 1 .00  Uhr
#
# Mo – Do
#  8.00 – 12.0 Uhr
# Mo,Mi, Do 1 .1  – 1.0 Uhr
# Di
# 1 .1  – 17.0 Uhr
# Fr
#  8.00 – 12.0 Uhr
#
# Zahnär ztlicher Not falldienst
# Organisation durch die Kassenzahnär ztliche Vereinigung (K ZV )
#
# 0221 /  7
#
# Mo – So 20.00 – .00  Uhr
#
# 7
#
# 7
#
#
#
#
#
#
#
# ===========《第39页》===========
# Mund-, Zahn-, K ieferklinik
#
# Poliklinik für Zahnär z tliche Prothetik
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Är ztlicher Direk tor: Prof. Dr. P. Rammelsberg
#
# Leitstelle und Ambulanz
#
# Sekretar iat
# 0221 /  02
#
# 0221 /  00
#
# Mo, Mi, Do 8.00 – 12.  Uhr
# 1 .1   – 17.00 Uhr
#  8.00 – 12.  Uhr
# 1 .1   – 18.00  Uhr
#  8.00 – 1 .00  Uhr
#
# Di
#
# Fr
#
# Myoar thropathiesprechstunde
#
# 0221 /  00
#
# Mo – Do  1 .00 – 17.00 Uhr
# Fr
# 10.00 – 1 .00 Uhr
#
# Implantatsprechstunde
#
# 0221 /  00
#
# Telefonische Auskünf te
# Mo – Do  1.00 – 17.00  Uhr
# Fr
# 10.00 – 1.00  Uhr
#
# 7
#
# 77
#
#
#
#
#
#
#
#
#
#
#
# ===========《第40页》===========
# Mund-, Zahn-, K ieferklinik
#
# K linik und Poliklinik für Mund-, K iefer- und Gesichtschirurg ie
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Är ztlicher Direk tor: Prof. Dr. Dr. J. Mühling
#
# Terminvereinbarung stationäre Aufnahme
#
# Pr ivatsprechstunde Professor Mühling
#
# Poliklinik , allgemeine Ambulanz
#
# Sekretar iat
# 0221 /  70
#
# 0221 /  8919
# Außerhalb der Dienstzeiten
# P for te  99
# und
#  999
#
# 0221 /  70
#
# 0221 /  7
#
# Mo – Do
# Fr
#
#  8.0 – 1 .00  Uhr
#  8.0 – 12.00  Uhr
#
# Implantatsprechstunde
#
# 0221 /  71
#
# Do
#
# 1 .00 – 1.00  Uhr
#
# Mundschleimhauterkrankungen
#
# 0221 /  71
#
# Fr
#
# 11.00 – 1 .00  Uhr
#
# Tumornachsorge
#
# 0221 /  71
# und
#  7
#
# Mo
#
# 1 .00 – 1 .00  Uhr
#
# Lippen- K iefer- Gaumenspalten
#
# 0221 /
#
# Mi
#
# 1 .00 – 1 .00  Uhr
#
# K iefer fehlstellungen (Dysgnathie)
#
# 0221 /  71
#
# Fr
#
# 10.00 – 12.00 Uhr
#
# Ästhetische Chirurgie / Plastische Chirurgie
#
# 0221 /  70
#
# 78
#
# 79
#
#
#
#
#
# ===========《第41页》===========
# Nationales Centrum für Tumorerkrankungen (NCT )
#
# Medizinische Onkolog ie
#
# Im Neuenheimer Feld 0 · 9120 Heidelberg
#
# Bereiche
#
# Är ztlicher Direk tor: Translationale Onkologie
# Prof. Dr. C . von Kalle
#
# Är ztlicher Direk tor: Medizinische Onkologie
# Prof. Dr. D. Jäger
#
# Pr ivatambulanz Prof. Dr. D. Jäger
#
# Anmeldung Sprechstunden
#
# Mo   Gastrointestinale Tumoren, Gynäkologische Tumoren,
# Allgemeine Onkologie
#
# Di
#
# CUP-Sprechstunde ( Tumoren unklarer Genese),
# Radioonkologie, Lymphom-Sprechstunde,
# Dermatologische Tumoren
#
# Mi  HNO -Tumoren, Myelom-Sprechstunde
#
# Do  Urologische Tumoren, Radioonkologie
#
# Fr
#
# Sarkom-Sprechstunde, Myelom-Sprechstunde
#
# Interdisziplinäre Tagesklinik I
#
# Interdisziplinäre Tagesklinik II
#
# Station I
#
# 80
#
# Telefon
#
# Sekretar iat
# 0221 /  990
#
# Sekretar iat
# 0221 /  7229
#
# 0221 /  801
#
# 06221 / 56 4801
#
# 0221 /  807
#
# 0221 /  8717
#
# 0221 /  82
#
# 81
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第42页》===========
# Neurochirurgische K linik
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. A . Unterberg
#
# Terminvereinbarung stationäre Aufnahme
# (Zentrales Patientenmanagement)
#
# Zeiten
#
# Mo – Fr
#
#  8.00 – 1.00  Uhr
#
# Telefon
#
# Sekretar iat
# 0221 /  01
#
# 0221 /  8099
#
# Pr ivatsprechstunde Professor Unterberg
#
# 0221 /  01
#
# Mi
#
#  8.00 – 1 .00  Uhr
#
# Leitstelle Ambulanz
#
# Notambulanz
#
# 0221 /  07
#
# 2 Std. er reichbar
# 0221 /  7211
# P for te  99
# und
#  999
#
# Anmeldung für Allgemeine und alle Spezialambulanzen
#
# 06221 / 56 6307
#
# Mo, Mi, Fr  8.0 – 1 .00  Uhr
#
# Pädiatr ische Neurochirurgie/ Wirbelsäulensprechstunde
#
# Di
#
#  8.0 – 1 .00  Uhr
#
# Tumorsprechstunde/ NCT
#
# Sprechstunde für chronische Schmer zen und
# Bewegungsstörungen - Funk tionelle Neurochirurgie -
#
# Hypophysensprechstunde
#
# Sprechstunde für Hydrozephalus und Syr ingomyelie
#
# Do
#
#  8.0 – 1 .00 Uhr
#
# Di
#
#  8.0 – 1 .00 Uhr
#
# Fr
#
#  8.0 – 1 .00 Uhr
#
# Do
#
#  8.0 – 1 .00  Uhr
#
# 82
#
# 8
#
#
#
#
#
#
#
# ===========《第43页》===========
# Neurologische K linik
#
# Neurolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. Dr. h.c. Dipl. Psych. W. Hacke
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  8211
#
# Terminvereinbarung stationäre Aufnahmen
#
# 0221 /
#
# Mo – Fr
#
#  8.00 – 1.00 Uhr
#
# Pr ivatambulanz
# Sekretar iat Prof. Dr. W. Hacke
# Sekretar iat Prof. Dr. H.-M . Meinck
# Oberar ztsekretar iat
#
# 0221 /  8211
# 0221 /  707
# 0221 /  70
#
# Mo – Fr
#
#  8.00 – 1.00  Uhr
#  (keine Not fälle)
#
# Allgemeine und Konsilambulanz
#
# 0221 /  710
#
# Mo – Fr
#
#  9.00 – 11.00  Uhr
# 1 .00 – 1 .00 Uhr
# (keine Not fälle)
#
# Not fallambulanz
#
# Stroke Unit
#
# Intensivstation
#
# Elek trophysiologische Anmeldungen
#
# 2 Std. er reichbar
# 0221 /  7211
# und P for te
# 0221 /  99
# und
#  999
#
# 2 Std. er reichbar
# 0221 /  782
# und
#  78
#
# 2 Std. er reichbar
# 0221 /  7779
#
# 0221 /  707
# (EMG -Labor)
# 0221 /  72
#
# Mo – Fr
#
#  8.00 – 1.00  Uhr
#
# 8
#
# 8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第44页》===========
# Neurologische K linik
#
# Neurolog ie
#
# Bereiche
#
# Ultraschall Anmeldungen
#
# Anmeldung für alle Sprechstunden
#
# Immunologie
#
# Bewegungssprechstunde
#
# Botox
#
# Neurovaskuläre Ambulanz
#
# Muskelsprechstunde
#
# Neurogenetik
#
# Schmer zambulanz
#
# Telefon
#
# Ambulanz
# 0221 /  710
#
# 06221 / 56 7510
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Zeiten
#
# Mo – Fr
#
#  9.00 – 11.00  Uhr
# 1 .00 – 1 .00 Uhr
#
# Mo – Fr
#
#  9.00 – 11.00  Uhr
# 1 .00 – 1 .00 Uhr
#
# Di und Mi  9.00 – 1 .00  Uhr
#
# Fr
#
#  11.00 – 1 .00 Uhr
#
# Mo
#
#  9.00 – 12.00  Uhr
#
# Do
#
#  9.00 – 1 .00  Uhr
#
# Di
#
#  9.00 – 1 .00  Uhr
#
# Mi
#
# 11.00 – 1 .00  Uhr
#
# Fr
#
#  11.00 – 12.00 Uhr
#
# 8
#
# 87
#
#
#
#
#
#
#
# ===========《第45页》===========
# Neurologische K linik
#
# Neuroradiolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. K . Sar tor
#
# Computer tomographie (CT )
#
# Magnetresonanztomographie (MRT )
#
# MRT-K inderklinik
#
# Magnetresonanzspek troskopie (MRS)
#
# Funk tionelle MRT (fMRT )
#
# Angiographie & Endovaskuläre Therapie
#
# CT-gesteuer te spinale Schmer ztherapie
#
# Second Opinion ( „Zweite Meinung“ )
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  7
#
# 0221 /  801
#
# 0221 /  801
#
# 0221 /  81
#
# 0221 /  7
# und
#  7
#
# 0221 /  7
# und
#  7
#
# 0221 /  777
#
# 0221 /  801
#
# 0221 /  7
#
# 88
#
# 89
#
#
#
#
#
# ===========《第46页》===========
# Neurologische K linik
#
# Neuroronkolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. W. Wick
#
# Terminvereinbarung stationäre Aufnahme
# (Zentrales Patientenmanagement)
#
# Ambulanz (NCT )
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  707
#
# 0221 /  8121
#
# 0221 /  8821
#
# 90
#
# 91
#
#
#
#
#
# ===========《第47页》===========
# Zentrum für Psychosoziale Medizin
#
# K linik für Allgemeine Psychiatr ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. C . Mundt
#
# Pr ivatambulanz Professor Mundt
#
# Voßstr. 2 · 911 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  271
# und
#  278
#
# 0221 /  1
# und
#
#
# Mo – Fr
#
#  9.00 – 12.00  Uhr
#
# Terminvereinbarung stationäre Annahme
#
# 0221 /
#
# Mo – Fr
#
#  9.00 – 17.  Uhr
#
# Not fälle
#
# Allgemeine Ambulanz
#
# 2 Std. er reichbar
# 0221 /
#
# 0221 /  1
# und
#  9
#
# Of fene Sprechstunde
# Mo – Fr
#  9.00 – 12.00  Uhr
#
# Nach Vereinbarung
# Mo, Mi, Do, Fr
#  9.00 – 17. Uhr
#  9.00 – 19.00 Uhr
#
# und Di
#
# Psychiatr ische Ambulanz für Kognitives Training (PAK T )
#
# 0221 /  1
#
# Mo – Fr
#
#  9.00 – 12.00 Uhr
#
# Psychoimmunologische (HIV-) Ambulanz
#
# 0221 /  1
# und
#  77
#
# Mo – Fr
#
#  9.00 – 12.00 Uhr
#
# Gedächtnisambulanz
#
# 0221 /
#
# Mo - Fr
#
#  8.00 – 12.00 Uhr
#
# Konsiliar- /Liaisonambulanz
#
# 0221 /  88
#
# Mo - Fr
#
#  9.00 – 12.00 Uhr
#
# 92
#
# 9
#
#
#
#
#
#
#
#
#
# ===========《第48页》===========
# Zentrum für Psychosoziale Medizin
#
# K linik für Allgemeine Psychiatr ie
#
# Voßstr. 2 · 911 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# Ambulanz des Frühbehandlungszentrums (FBZ )
#
# Mut ter-K ind-Ambulanz
#
# 0221 /  1
# und
#  89
#
# 0221 /   1
# und
#  89
#
# Mo – Fr
#
#  9.00 – 12.00  Uhr
#
# Mo - Fr
#
#  9.00 – 12.00 Uhr
#
# „Balance“ – Angebot für K inder psychisch kranker Eltern
#
# 0221 /
# und  0179 / 80192
#
# Mo – Fr
#
#  9.00 – 17.00  Uhr
#
# 9
#
# 9
#
#
#
# ===========《第49页》===========
# Zentrum für Psychosoziale Medizin
#
# Psychosomatische und allgemeine klinische Medizin
#
# Im Neuenheimer Feld 10 · 9120 Heidelberg
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. W. Her zog
# Neue Medizinische K linik
#
# Altklinikum Bergheim
#
# Anmeldung für alle Ambulanzen
#
# Internistisch-Psychosomatische Ambulanz
# (Neue Medizinische K linik)
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  89
#
# Sekretar iat
# 0221 /  879
#
# 0221 /  877
#
# Mo – Do
# und
# Fr
#
#  8.00 – 12.00 Uhr
# 1 .00 – 1 .0 Uhr
#  8.00 – 12.0  Uhr
#
# Mo
# und
# Mi
# Do
#
#  9.00 – 12.00 Uhr
# 1 .00 – 1 .00  Uhr
# 11.00 – 1 .00 Uhr
#  8.0 – 11.0  Uhr
#
# Allgemein- internistische Ambulanz (Neue Medizinische K linik)
#
# Mo – Fr
#
#  8.00 – 12.00 Uhr
#
# Rheuma-/ Schmer zambulanz (Neue Medizinische K linik)
#
# Mo, Mi, Do 8.00 – 12.00 Uhr
#
# Psychosomatische Not fallversorgung
#
# Not fallambulanz
#
# 1.0  –  8.00  Uhr
#
# Dienstar zt
# 011 / 1792
# Oberar zt
# 011 / 11127
#
# 2 Std. er reichbar
# 0221 /  8781
# und
#  8782
#
# 9
#
# 97
#
#
#
#
#
#
#
#
#
#
#
# ===========《第50页》===========
# Zentrum für Psychosoziale Medizin
#
# K linik für K inder- und Jugendpsychiatr ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. F. Resch
#
# Blumenstraße 8 -10 · 911 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  918
#
# Anmeldung Neuvorstellungen
#
# 0221 /  91
#
# Mo – Fr
#
# 10.00 – 1 .00 Uhr
#
# Not fälle
#
# 2 Std. er reichbar
# Während der Dienstzeit
# 0221 /  91
# und
#  91
# Außerhalb der Dienstzeit
# 0221 /
#
# Anmeldung für alle Spezialambulanzen
#
# 06221 / 56 6914
#
# Ambulanz für Essstörungen
#
# Ambulanz für autistische K inder
#
# Ambulanz für K inder mit ADHS und expansiven Störungen
#
# Ambulanz für K inder und Jugendliche mit
# chronischen körper lichen Erkrankungen
#
# Ambulanz für Jugendliche mit Border line -Störungen
#
# Konsiliar-/ Liaisondienst
#
# 98
#
# 99
#
#
#
# ===========《第51页》===========
# Zentrum für Psychosoziale Medizin
#
# K linik für K inder- und Jugendpsychiatr ie
#
# Blumenstraße 8 -10 · 911 Heidelberg
#
# Bereiche
#
# Telefon
#
# Zeiten
#
# „Balance“ - Angebot für K inder psychisch kranker Eltern
#
# Psychoonkologie
#
# Ambulanz des Frühbehandlungszentrums (FBZ ) inkl. aufsuchende
# ambulante Behandlung (Mobiles Bezugspersonensystem)
#
# Interdisziplinäre Sprechstunde für Eltern mit Säug lingen
# und K leinkindern
#
# 0221 /
# und  0179 / 8 01 92
#
# 0221 /  8789
#
# 0221 /  2
#
# Sekretar iat
# Familientherapie
# 0221 /  701
#
# Mo – Do
# Fr
#
#  9.00 – 1 .00 Uhr
#  9.00 – 1 .0 Uhr
#
# 100
#
# 101
#
#
#
# ===========《第52页》===========
# Zentrum für Psychosoziale Medizin
#
# Institut für Medizinische Psycholog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. Rolf Ver res
#
# Pr ivatambulanz Prof. Ver res
#
# Bergheimer Str. 20 · 911 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  811
#
# 0221 /  810
#
# Ambulanz für Psych. Beratung bei uner fülltem K inder wunsch
#
# 0221 /  817
#
# Ambulanz für Musikpsychotherapie, Stimm- und Atemtherapie
#
# 0221 /  810
#
# Ambulanz für Systemische Familientherapie
# (Schwerpunkt: psychosomatische und psychiatrische Störungsbilder)
#
# 0221 /  812
#
# Allgemeine psychotherapeutische Ambulanz
#
# 0221 /  811
#
# 102
#
# 10
#
# ===========《第53页》===========
# Zentrum für Psychosoziale Medizin
#
# Institut für Psychosomatische Kooperationsforschung
# und Familientherapie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. med. M . Cierpka
#
# Anmeldung für  alle Spezialambulanzen
#
# Spezialambulanz für Eltern mit Säug lingen und K leinkindern
#
# Spezialambulanz für ältere Paare
#
# Spezialambulanz für Familienmedizin
#
# Bergheimer Str.  · 911 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  701
#
# 06221 / 56 4701
#
# 10
#
# 10
#
#
#
#
#
# ===========《第54页》===========
# Radiologische K linik
#
# Radioonkolog ie und Strahlentherapie
#
# Bereiche
#
# Radiologische Ambulanz
#
# Radioonkologie und Strahlentherapie
#
# Är ztlicher Direk tor: Prof. Dr. Dr. J. Debus
#
# Pr ivatambulanz Professor Debus
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# 0221 /  711
#
# Mo – Fr
#
# 8.00 – 1.00  Uhr
#
# Sekretar iat
# 0221 /  8201
# und
#  8202
#
# 0221 /  70
#
# Allgemeine Ambulanz
#
# 0221 /  711
#
# Mo – Fr
#
#  8.00 – 1.00  Uhr
#
# Anmeldung für alle Spezialsprechstunden
#
# 06221 / 56 7611
#
# Gynäkologische Tumore, Brust-Sprechstunde
#
# HNO -Tumore
#
# Lymphome,Plasmozy tom
#
# Urologische Tumore
#
# Pankreas, Rek tum, Ösophagus, Magen
#
# Mo
# Di – Do
#
# 1 .00 – 1 .0  Uhr
# 1 .00 – 1 .0  Uhr
#
# Mo und Do 8.00 –  9.00 Uhr
#
# Di (NCT ), Fr 8.0 – 10.00  Uhr
#
# Mo
#  9.00 – 10.0  Uhr
# Mi
#  8.00 –  9.00  Uhr
# Do
#  8.0 – 10.00  Uhr
# (NCT ) Prostatasprechstunde
#
# Mo – Mi, Fr  8.0 –  9.0  Uhr
# Do
# 12.0 – 1 .0  Uhr
#
# 10
#
# 107
#
# ===========《第55页》===========
# Radiologische K linik
#
# Radioonkolog ie und Strahlentherapie
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Bereiche
#
# K inder
#
# Sarkome
#
# Hirntumore
#
# Ar ter iovenöse Missbildungen (AVM)
#
# Heidelberger Ionenstrahl-Therapiezentrum (HIT )
# Protonen- und Schwer ionentherapie
#
# Behandlungsbeginn geplant ab Ende 2007
#
# Är ztlicher Direk tor: Prof. Dr. Dr. J. Debus
#
# Zeiten
#
# Mo
#
# 12.0 – 1 .00  Uhr
#
# Mo
# Fr (NCT )
#
#  8.0 – 10.00  Uhr
# 12.0 – 1 .00  Uhr
#
# Di
# 12.0 – 1 .00  Uhr
# Do und Fr   8.0 – 10.00  Uhr
#
# Mo und Di  nachmit tags
#
# Sekretar iat
# 0221 /  8201
# und
#  8202
#
# Allgemeine Ambulanz
#
# 0221 /  711
#
# Mo – Fr
#
# 8.00 - 1.00 Uhr
#
# 108
#
# 109
#
#
#
# ===========《第56页》===========
# Radiologische K linik
#
# Radiodiagnostik
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. G. W. Kauf fmann
#
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Telefon
#
# Sekretar iat
# 0221 /  10
#
# Sek tion Radiologische Diagnostik in der Med. K linik
#
# 0221 /  8089
#
# Inter ventionelle Radiologie
#
# Gastroenterologische Radiodiagnostik
#
# Muskuloskelet tale Radiodiagnostik
#
# Sek tion Urogenitale Radiodiagnostik
#
# Sek tion Senologie (Mammographie/MRT )
#
# RIZ
# Radiologie Informationszentrum:
# Zentrale für Beratung und Terminvereinbarung
#
# 0221 /
#
# 0221 /
#
# 0221 /  8080
#
# 0221 /  18
#
# 0221 /  21
#
# 0221 /  27
#
# 110
#
# 111
#
#
#
# ===========《第57页》===========
# Radiologische K linik
#
# Abteilung Nuklearmedizin
# Abteilung Pädiatr ische Radiolog ie
#
# Bereiche
#
# Är ztlicher Direk tor: Prof. Dr. U. Haberkorn
#
# Terminvereinbarung stationäre Aufnahme
# Stationsleitung
#
# Im Neuenheimer Feld 00 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Sekretar iat
# 0221 /  771
#
# 0221 /  77
#
# Ambulanz Nuklearmedizin
#
# 0221 /  772
#
# Mo – Fr
#
#  8.00 – 1.00  Uhr
#
# Abteilung Pädiatrische Radiologie
#
# Är ztlicher Direk tor: Prof. Dr. J. Tröger
#
# Röntgen-Anmeldung (Leitstelle)
#
# Not fallambulanz der K inderklinik
#
# Sekretar iat
# 0221 /  229
#
# 0221 /  20
#
# 2 Std. er reichbar
# 0221 /  219
#
# Mo – Fr
# Sa
#
#  8.00 – 17.00  Uhr
# 10.00 – 12.00 Uhr
#
# 112
#
# 11
#
#
#
#
#
# ===========《第58页》===========
# Institut für Humangenetik
#
# Im Neuenheimer Feld  · 9120 Heidelberg
#
# Bereiche
#
# Abteilung Humangenetik
#
# Är ztlicher Direk tor: Prof. Dr. C . R . Bar tram
#
# Genetische Poliklinik
#
# Leiter: Prof. Dr. Dr. J. Zschocke
#
# Ambulanz
#
# Genetische Labordiagnostik
#
# Chromosomenanalyse, postnatal
#
# Chromosomenanalyse, pränatal
#
# Tumor zy togenetik
#
# Molekulare Zy togenetik (F ISH)
#
# Molekulargenetik
#
# Telefon
#
# Sekretar iat
# 0221 /  11
#
# Sekretar iat
# 0221 /  088
#
# 0221 /  087
#
# 0221 /  09
#
# 0221 /  092
#
# 0221 /  09
#
# 0221 /  07
# und
#  0
#
# 0221 /  98
#
# 11
#
# 11
#
# ===========《第59页》===========
# Hygieneinstitut
#
# Bereiche
#
# Im Neuenheimer Feld 2 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Abteilung Hygiene und Medizinische Mikrobiologie
#
# Är ztlicher Direk tor: Prof. Dr. K . Heeg
#
# 0221 /  811
#
# Mikrobiologische Diagnostik
#
# 0221 /  7821
# Letzte halbe Stunde
# der regulären Dienstzeit
# 0221 /  8092
# und
#  809
#
# Mo – Fr
#  7.0 – 18.00  Uhr
# Sa und Vor feier tage
#  7.0 – 12.00  Uhr
# So und Feier tage
# 10.00 – 12.00 Uhr
#
# Rufbereitschaf t (außerhalb der Dienstzeiten)
#
# 0171 /  0 087
#
# Befundabf rage
#
# Är ztliche Beratung
#
# Krankenhaus- und Umwelthygiene
#
# Abteilung  Parasitologie
#
# Är ztlicher Direk tor: Prof. Dr. M . Lanzer
# Fachaufsicht Labor: Dr. T. Junghanss
#
# Diagnostisches Labor
#
# 0221 /  8092
#
# 0221 /  809
#
# 0221 /  9999
# Außerhalb der Dienstzeiten
# 0171 / 0087
#
# Mo – Fr
#
#  8.00 – 1.00  Uhr
#
# 0221 /  90
#
# 0221 /  78
#
# 11
#
# 117
#
#
#
#
#
# ===========《第60页》===========
# WARNING:root:Literal required: CIDSystemInfo
# Hygieneinstitut
#
# Bereiche
#
# Abteilung V irologie
#
# Im Neuenheimer Feld 2 · 9120 Heidelberg
#
# Telefon
#
# Zeiten
#
# Är ztlicher Direk tor: Prof. Dr. H.-G. Kräusslich
#
# 0221 /  001
#
# Mo – Fr
#
#  8.00 – 1.0 Uhr
#
# 0221 /  021
# Diensthabender Ar zt
# 0221 /  021
# Außerhalb der Dienstzeiten
# 0171 / 0089
#
# Abteilung Tropenhygiene und öf fentliches Gesundheitswesen
#
# Är ztlicher Direk tor: Prof. Dr. R . Sauerborn
#
# 0221 /
#
# Tropenmedizinische Ambulanz
#
# Nacht- und Wochenenddienst für Not fälle
# (v.a. bei Verdacht auf MAL ARIA)
# Not fallambulanz der Medizinischen K linik
#
# Impfsprechstunde
#
# Spezialsprechstunde Echinokokkose
#
# 0221 /  2999
# und
#  290
# Diensthabender Ar zt
# 0221 /  90
#
# 0221 /  8781
# und
#  8782
#
# 0221 /  2999
# und
#  290
#
# 0221 /  2999
# und
#  290
#
# Mo – Fr
#
#  8.00 – 17.00  Uhr
#
# Di und Mi  1 .00 – 1.00 Uhr
#
# Mo – Fr  nach Vereinbarung
#
# 118
#
# 119
#
#
#
# ===========《第61页》===========
# Institut für Immunologie
#
# Im Neuenheimer Feld 0 · 9120 Heidelberg
#
# Bereiche
#
# Telefon
#
# Abteilung Allgemeine Immunologie, Serologie,
# Hämatologische Diagnostik mit Blutbank
#
# Är ztlicher Direk tor: Prof. Dr. S. Meuer
#
# 0221 /  000
#
# Speziallabors
#
# Immunbiologie
#
# Immunchemie
#
# Zelluläre Immologie
#
# IK T Z gGmbH - Transfusionsmedizin Blutbank (Blutspendedienst)
#
# Molekulare Immundiagnostik
#
# Abteilung Transplantationsimmunologie
#
# 0221 /  02
#
# 0221 /  02
#
# 0221 /  7
#
# 0221 /  00
#
# 0221 /  012
#
# Är ztlicher Direk tor: Prof. Dr. G. Opelz
#
# 0221 /  01
#
# Speziallabors
#
# HL A - Typisierungslabor
#
# Antikörper labor
#
# Zelluläre Immunologie
#
# Heidelberger Stammzellspender Register (HSR)
#
# Koordinationsstelle für nicht ver wandte
# Knochenmarkspendersuche
#
# 0221 /  007
#
# 0221 /
#
# 0221 /  019
#
# 0221 /  9809
#
# 0221 /  00
#
# 120
#
# 121
#
#
#
# ===========《第62页》===========
# Pathologisches Institut
#
# Im Neuenheimer Feld 220/221 · 9120 Heidelberg
#
# Bereiche
#
# Abteilung Allgemeine Pathologie
#
# Telefon
#
# Är ztlicher Direk tor: Prof. Dr. P. Schirmacher
#
# 0221 /  201
#
# Abteilung Neuropathologie
#
# Är ztlicher Direk tor: Prof. Dr. A . Deimling
#
# 0221 /  20
#
# 122
#
# 12
#
#
#
# ===========《第63页》===========
#  69120 Heidelberg
#
# Zentrallabor
#
# Bereiche
#
# Befundauskunf t
#
# Dienstar zt
#
# Im Neuenheimer Feld 71 · 9120 Heidelberg
#
# Telefon
#
# 2 Std. er reichbar
# 0221 /  880
#
# 0221 /  8802
#
# Zeiten
#
# Mo – So
#
# Mo – Fr
#  7.0 – 18.00  Uhr
# Sa, So und Feier tage
#  9.00 – 1 .00  Uhr
#
# 12
#
# 12
#
#
#
#
#
#
#
# ===========《第64页》===========
# Sozialdienst
#
# Bereiche
#
# Augenklinik
#
# Chirurgische K linik
#
# Frauenklinik
#
# Hautklinik
#
# HNO -K linik
#
# Kinderklinik
#
# Allgemeine Pädiatr ie
#
# Pädiatr ische Onkologie, Immunologie, Pneumonologie
#
# Pädiatr ische Neurologie
#
# Medizinische Klinik
#
# Abteilung I, III & IV
#
# Abteilung V
#
# 12
#
# Telefon
#
# 0221 /  2
#
# 0221 /  27
#
# 0221 /  91
#
# 0221 /  822
#
# 0221 /  7
#
# 0221 /  87
#  87
#  88
#
# und
#
# 0221 /  9807
# und
#  888
#
# 0221 /  79
#
# 0221 /  87
# und
#  2
#
# 0221 /  2792
# und
#  870
#
# 127
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第65页》===========
# Sozialdienst
#
# Bereiche
#
# Mund-K iefer-Gesichtschirurgie
#
# Neurochirurgie
#
# Neurologische K linik
#
# Radiologische K linik
#
# Zentrum für Psychosoziale Medizin -
# Klinik für Allgemeine Psychiatrie
#
# Ambulanz, Balance, Station von Baeyer
#
# Station Mayer-Groß, Station Gruhle
#
# Sek tion Gerontopsychiatr ie -
# Station Tellenbach und Gedächtnisambulanz
#
# Station Roller, Station von Gebsat tel
#
# Station Jaspers, Station Gruhle
#
# Frühbehandlungszentrum, Tagesklinik
#
# Zentrum für Psychosoziale Medizin -
# Klinik für Psychosomatische und Allgemeine Klinische Medizin
#
# Altklinikum Bergheim
#
# Abteilung II, Allgemeine K linische und
# Psychosomatische Medizin
#
# 128
#
# Telefon
#
# 0221 /  022
#
# 0221 /  721
#
# 0221 /  21
#
# 0221 /  2
# 0221 /  801
#
# 0221 /
#
# 0221 /  91
#
# 0221 /  21
#
# 0221 /
#
# 0221 /  98
#
# 0221 /  71
#
# 0221 /  2
# 0221 /  89
#
# 0221 /  80
#
# 129
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第66页》===========
# Weitere Ansprechpar tner
#
# Bereiche
#
# Telefon
#
# Abteilung Allgemeinmedizin und Versorgungsforschung
# (HeiCuMed/Lehrpraxen)
#
# Voßstr. 2
# 9120 Heidelberg
#
# Är ztlicher Direk tor: Prof. Dr. J. Szecsenyi
#
# Sekretaraiat
# 0221 /  7
#
# Ar zneimit tel- Informations-Dienst (HeiCare/ AiD Praxis)
#
# 0221 /  82
#
# Arbeitsschwerpunk t Lehre
# Dr. P. Engeser
#
# Qualitätsmagement / Medizincontrolling
#
# Staabsstelle des K linikumsvorstandes
# Im Neuenheimer Feld 72
# 9120 Heidelberg
#
# Medizinische Kooperationen
# Zusammenarbeit mit niedergelassenen Är zten
#
# K linikumsver waltung
# Im Neuenheimer Feld 72
# 9120 Heidelberg
#
# M . Gudera
#
# Sekretar iat
# 0221 /  81
#
# 0221 /  2
#
# 0221 /  7090
#
# 10
#
# 11
#
#
#
# ===========《第67页》===========
# WARNING:pdfminer.layout:Too many boxes (367) to group, skipping.
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Übersichtsplan
#
# Heidelberg und K linikum
#
# Heiligenberganlage
#
# Heiligenbergturm
#
# <> Mannheim
# Flughafen
# A 656
#
# 161
#
# S
# a
# u
#
# t
#
# w
#
# e
# h
#
# r
#
# ZOO
#
# DJH
#
# TSG
#
# Bismarcksäule
#
# Bunsenplatz
#
# A
#
# l
# t
#
# e
# B
#
# r
#
# ü
# c
# k
# e
#
# M a r k t -
# p l a t z
#
# U n i
# -
# p l a t z
#
# E
#
# r
#
# n
# s
#
# t
# -
#
# W
#
# a
# z
#
# l
#
# -
#
# B
# ü
# c
# k
# e
#
# r
#
# T
# H
# h
# B
# e
# e
# o
# ü
# u
# d
# c
# s
# k
# o
# s
# e
#
# r
#
# -
#
# -
#
# r
#
# Römerkreis
#
# Hauptbahnhof
#
# > R
# <
#
# h
# c
# a
# b
# h
# o
#
# r
#
# N e c k a r g e m ü n d > >
#
# <
#
# <
#
# M
#
# a
#
# n
#
# n
#
# h
#
# e
#
# i
#
# m
#
#  N e c k a r
#
# Med.
# Klinik
# 0
# 16
#
# A d e n a u e r -
# P l a t z
#
# B
#
# i
#
# s
#
# m
#
# a
#
# r
#
# c
#
# k
#
# P
#
# l
#
# a
#
# t
#
# z
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# 24
# P
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# S c h u r m a n s
#
# t
#
# r
#
# .
#
# B e r g h e i m e r
#
#  S t
#
# r a ß e
#
# H
#
# a
#
# n
#
# d
#
# s
#
# c
#
# h
#
# u
#
# h
#
# s
#
# h
#
# e
#
# i
#
# m
#
# e
#
# r
#
# L
#
# a
#
# n
#
# d
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# B 3
#
# M
#
# a
# n
# n
# h
# eim
# er Str.
#
# B l u m e n t h a l s t
#
# r a ß e
#
# T
#
# i
#
# e
#
# r
#
# g
#
# a
#
# r
#
# t
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# K l a u s
#
# e n p f a d
#
# M ö n c h h o f s t r a ß e
#
# K i rschne rst raße
#
# Jahnstraße
#
# B
#
# r
#
# ü
# c
# k
# e
# n
# s
#
# t
# r
#
# a
# ß
# e
#
# F
#
# e
#
# h
#
# r
#
# e
#
# n
#
# z
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# Philosophenweg
#
# P l ö ck
#
# e
# s
# s
# a
# g
# n
# e
# s
# n
# u
# B
#
# N e c k a r s t
#
# r a ß e
#
# A m H a c k t e u f e l
#
# H a u p t s t r a ß e
#
# G
#
# r
#
# a
#
# b
#
# e
#
# n
#
# g
#
# a
#
# s
#
# s
#
# e
#
# F
#
# r
#
# i
#
# e
#
# d
#
# r
#
# i
#
# c
# h
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# M
#
# t
# t
# i
#
# e
#
# r
#
# m
#
# a
#
# i
#
# e
#
# r
#
# s
#
# .
# r
# t
#
# Uferstraße
#
# S
#
# o
#
# f
#
# i
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# e
# h
# c
# a
# b
# h
# o
# R
#
# r
#
# r
# t
# r S
#
# e
# ß
# a
#
# Bergheimer Straße
#
# Czernybrücke
#
# Blumenstr.
#
# N e u e n h e i m e r
#
# L a n d s
#
# t
#
# r a ß e
#
# H
#
# o
#
# s
#
# p
#
# i
#
# t
#
# a
#
# l
#
# s
#
# t
#
# r
#
# .
#
# T
#
# h
#
# i
#
# b
#
# a
#
# u
#
# t
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# F r
#
# i e d r
#
# i c h - E b e r
#
# t
#
# - A n l a g e
#
# <> Eppelheim
#
# R
# ö
#
# m
#
# e
#
# r
#
# s
#
# t
# r
#
# a
# ß
# e
#
# V o ß s t
#
# r a ß e
#
# S
#
# e
# n
# h
# c
#
# i
#
# d
#
# m
#
# h
# ü
#
# l
#
# s
#
# t
#
# r
#
# .
#
# u
# L
#
# i
#
# s
# n
# e
# s
#
# .
# r
# t
#
# H
# e
# u
# s
# c
# h
# e
# u
# e
#
# r
#
# Im Neuenheimer Feld
# (INF)
#
# T
#
# i
#
# e
#
# r
#
# g
#
# a
#
# r
#
# t
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# B
#
# e
#
# i
# l
# r
#
# e
# n
#
# r
#
# s
#
# r
# t
#
# a
#
# ß
#
# e
#
# Vangerowstraße
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# 28
#
# 17
#
# 18
#
# 20
#
# 21
#
# 23
#
# 27
#
# 26
#
# 25
#
# 22
#
# 29
# 30
#
# 5
#
# 7
#
# 4
#
# 3
#
# 6
#
# 13
#
# 14
#
# 15
#
# 16
#
# 1
#
# 2
#
# 8
#
# 9
#
# 10
#
# 11a
#
# 12
#
# 11
#
# 12
#
# 1
#
#
#
#
#
#
#
# ===========《第68页》===========
# WARNING:pdfminer.layout:Too many boxes (721) to group, skipping.
# Im Neuenheimer Feld 110 · 9120 Heidelberg
#
# Wege und Pläne
#
# K linikum Im Neuenheimer Feld und Bergheim
#
# Heiligenberganlage
#
# Heiligenbergturm
#
# <> Mannheim
# Flughafen
# A 656
#
# 161
#
# S
# a
# u
#
# t
#
# w
#
# e
# h
#
# r
#
# ZOO
#
# DJH
#
# TSG
#
# Bismarcksäule
#
# Bunsenplatz
#
# A
#
# l
# t
#
# e
# B
#
# r
#
# ü
# c
# k
# e
#
# M a r k t -
# p l a t z
#
# U n i
# -
# p l a t z
#
# E
#
# r
#
# n
# s
#
# t
# -
#
# W
#
# a
# z
#
# l
#
# -
#
# B
# ü
# c
# k
# e
#
# r
#
# T
# H
# h
# B
# e
# e
# o
# ü
# u
# d
# c
# s
# k
# o
# s
# e
#
# r
#
# -
#
# -
#
# r
#
# Römerkreis
#
# Hauptbahnhof
#
# > R
# <
#
# h
# c
# a
# b
# h
# o
#
# r
#
# N e c k a r g e m ü n d > >
#
# <
# s
# <
# e
# n
#
# M
#
# a
#
# i
# n
# l
# r
#
# n
#
# h
#
# e
#
# i
#
# m
#
# N e c k a r g e m ü n d > >
#  N e c k a r
#
# Med.
# Klinik
# 0
# 16
#
# A d e n a u e r -
# P l a t z
#
# B
#
# i
#
# s
#
# m
#
# a
#
# r
#
# c
#
# k
#
# P
#
# l
#
# a
#
# t
#
# z
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# 24
# P
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# S c h u r m a n s
#
# t
#
# r
#
# .
#
# B e r g h e i m e r
#
#  S t
#
# r a ß e
#
# H
#
# a
#
# n
#
# d
#
# s
#
# c
#
# h
#
# u
#
# h
#
# s
#
# h
#
# e
#
# i
#
# m
#
# e
#
# r
#
# L
#
# a
#
# n
#
# d
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# B 3
#
# M
#
# a
# n
# n
# h
# eim
# er Str.
#
# B l u m e n t h a l s t
#
# r a ß e
#
# T
#
# i
#
# e
#
# r
#
# g
#
# a
#
# r
#
# t
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# K l a u s
#
# e n p f a d
#
# M ö n c h h o f s t r a ß e
#
# K i rschne rst raße
#
# Jahnstraße
#
# B
#
# r
#
# ü
# c
# k
# e
# n
# s
#
# t
# r
#
# a
# ß
# e
#
# F
#
# e
#
# h
#
# r
#
# e
#
# n
#
# z
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# Philosophenweg
#
# P l ö ck
#
# e
# s
# s
# a
# g
# n
# e
# s
# n
# u
# B
#
# N e c k a r s t
#
# r a ß e
#
# A m H a c k t e u f e l
#
# H a u p t s t r a ß e
#
# G
#
# r
#
# a
#
# b
#
# e
#
# n
#
# g
#
# a
#
# s
#
# s
#
# e
#
# F
#
# r
#
# i
#
# e
#
# d
#
# r
#
# i
#
# c
# h
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# M
#
# t
# t
# i
#
# e
#
# r
#
# m
#
# a
#
# i
#
# e
#
# r
#
# s
#
# .
# r
# t
#
# Uferstraße
#
# S
#
# o
#
# f
#
# i
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# e
# h
# c
# a
# b
# h
# o
# R
#
# r
#
# r
# t
# r S
#
# e
# ß
# a
#
# Bergheimer Straße
#
# Czernybrücke
#
# Blumenstr.
#
# N e u e n h e i m e r
#
# L a n d s
#
# t
#
# r a ß e
#
# H
#
# o
#
# s
#
# p
#
# i
#
# t
#
# a
#
# l
#
# s
#
# t
#
# r
#
# .
#
# T
#
# h
#
# i
#
# b
# G
#
# a
#
# a
# u
#
# t
#
# b
# s
# e
#
# t
#
# r
#
# a
# g
#
# ß
# a
#
# e
# s
#
# F r
#
# i e d r
#
# i c h - E b e r
#
# t
#
# - A n l a g e
#
# <> Eppelheim
#
# R
# ö
#
# m
#
# e
#
# r
#
# s
#
# t
# r
#
# a
# ß
# e
#
# V o ß s t
#
# r a ß e
#
# e
# n
# h
# c
# S
#
# i
#
# d
#
# m
#
# h
# ü
#
# l
#
# s
#
# t
#
# r
#
# .
#
# u
# L
#
# i
#
# s
# n
# e
# s
#
# .
# r
# t
#
# H
# e
# u
# s
# c
# h
# e
# u
# e
#
# r
#
# Im Neuenheimer Feld
# (INF)
#
# T
#
# i
#
# e
#
# r
#
# g
#
# a
#
# r
#
# t
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# B
#
# e
#
# i
# l
# r
#
# e
# n
#
# r
#
# s
#
# r
# t
#
# e
# ß
# a
#
# Vangerowstraße
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# 28
#
# 17
#
# 18
#
# 20
#
# 21
#
# 23
#
# 27
#
# 26
#
# 25
#
# 22
#
# 29
# 30
#
# 5
#
# 7
#
# 4
#
# 3
#
# 6
#
# 13
#
# 14
#
# 15
#
# 16
#
# 1
#
# 2
#
# 8
#
# 9
#
# 10
#
# 11a
#
# 12
#
# 11
#
# Heiligenberganlage
#
# Heiligenbergturm
#
# <> Mannheim
# Flughafen
# A 656
#
# 161
#
# S
# a
# u
#
# t
#
# w
#
# e
# h
#
# r
#
# ZOO
#
# DJH
#
# TSG
#
# Bismarcksäule
#
# Bunsenplatz
#
# A
#
# l
# t
#
# e
# B
#
# r
#
# ü
# c
# k
# e
#
# M a r k t -
# p l a t z
#
# U n i
# -
# p l a t z
#
# E
#
# r
#
# n
# s
#
# t
# -
#
# W
#
# a
# z
#
# l
#
# -
#
# B
# ü
# c
# k
# e
#
# r
#
# T
# H
# h
# B
# e
# e
# o
# ü
# u
# d
# c
# s
# k
# o
# s
# e
#
# r
#
# -
#
# -
#
# r
#
# Römerkreis
#
# Hauptbahnhof
#
# > R
# <
#
# h
# c
# a
# b
# h
# o
#
# r
#
# <
#
# <
#
# M
#
# a
#
# n
#
# n
#
# h
#
# e
#
# i
#
# m
#
#  N e c k a r
#
# Med.
# Klinik
# 0
# 16
#
# A d e n a u e r -
# P l a t z
#
# B
#
# i
#
# s
#
# m
#
# a
#
# r
#
# c
#
# k
#
# P
#
# l
#
# a
#
# t
#
# z
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# P
#
# 24
# P
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# S c h u r m a n s
#
# t
#
# r
#
# .
#
# B e r g h e i m e r
#
#  S t
#
# r a ß e
#
# H
#
# a
#
# n
#
# d
#
# s
#
# c
#
# h
#
# u
#
# h
#
# s
#
# h
#
# e
#
# i
#
# m
#
# e
#
# r
#
# L
#
# a
#
# n
#
# d
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# B 3
#
# M
#
# a
# n
# n
# h
# eim
# er Str.
#
# B l u m e n t h a l s t
#
# r a ß e
#
# T
#
# i
#
# e
#
# r
#
# g
#
# a
#
# r
#
# t
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# K l a u s
#
# e n p f a d
#
# M ö n c h h o f s t r a ß e
#
# K i rschne rst raße
#
# Jahnstraße
#
# B
#
# r
#
# ü
# c
# k
# e
# n
# s
#
# t
# r
#
# a
# ß
# e
#
# F
#
# e
#
# h
#
# r
#
# e
#
# n
#
# z
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# Philosophenweg
#
# P l ö ck
#
# e
# s
# s
# a
# g
# n
# e
# s
# n
# u
# B
#
# N e c k a r s t
#
# r a ß e
#
# A m H a c k t e u f e l
#
# H a u p t s t r a ß e
#
# r
#
# n
#
# s
#
# e
#
# F
#
# r
#
# i
#
# e
#
# d
#
# r
#
# i
#
# c
# h
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# M
#
# t
# t
# i
#
# e
#
# r
#
# m
#
# a
#
# i
#
# e
#
# r
#
# s
#
# .
# r
# t
#
# Uferstraße
#
# S
#
# o
#
# f
#
# i
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# e
# h
# c
# a
# b
# h
# o
# R
#
# r
#
# r
# t
# r S
#
# e
# ß
# a
#
# Bergheimer Straße
#
# Czernybrücke
#
# Blumenstr.
#
# N e u e n h e i m e r
#
# L a n d s
#
# t
#
# r a ß e
#
# H
#
# o
#
# s
#
# p
#
# i
#
# t
#
# a
#
# l
#
# s
#
# t
#
# r
#
# .
#
# T
#
# h
#
# i
#
# b
#
# a
#
# u
#
# t
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# F r
#
# i e d r
#
# i c h - E b e r
#
# t
#
# - A n l a g e
#
# <> Eppelheim
#
# R
# ö
#
# m
#
# e
#
# r
#
# s
#
# t
# r
#
# a
# ß
# e
#
# V o ß s t
#
# r a ß e
#
# S
#
# e
# n
# h
# c
#
# i
#
# d
#
# m
#
# h
# ü
#
# l
#
# s
#
# t
#
# r
#
# .
#
# u
# L
#
# i
#
# s
# n
# e
# s
#
# .
# r
# t
#
# H
# e
# u
# s
# c
# h
# e
# u
# e
#
# r
#
# Im Neuenheimer Feld
# (INF)
#
# T
#
# i
#
# e
#
# r
#
# g
#
# a
#
# r
#
# t
#
# e
#
# n
#
# s
#
# t
#
# r
#
# a
#
# ß
#
# e
#
# B
#
# e
#
# r
#
# r
# t
#
# a
#
# ß
#
# e
#
# Vangerowstraße
#
# H
#
# H
#
# H
#
# H
#
# H
#
# H
#
# 28
#
# 17
#
# 18
#
# 20
#
# 21
#
# 23
#
# 27
#
# 26
#
# 25
#
# 22
#
# 29
# 30
#
# 5
#
# 7
#
# 4
#
# 3
#
# 6
#
# 13
#
# 14
#
# 15
#
# 16
#
# 1
#
# 2
#
# 8
#
# 9
#
# 10
#
# 11a
#
# 12
#
# 11
#
# Klinikum Im Neuenheimer Feld
#
# 1
# Kopf klinik
# 2  Medizinische K linik
#
# K inderklinik
#
# Schmer zzentrum
#
# Chirurgische K linik
#
# Pathologisches Institut
# 7
# DKF Z
# 8
# Hygieneinstitut
# 9
# Institut für Immunologie
# 10
# Theoretikum
# 11
# Institut für Humangenetik
# 11a Genetische Poliklinik
# 12  Ot to Meyerhof Zentrum
# 1
# VZM/Apotheke
# 1  Ver waltung/ZIM
# 1
# Ionentherapie/HIT
# 1
# Zentrallabor
#
# INF 00
# INF 10
# INF 1
# INF 11
# INF 110
# INF 220/221
# INF 280
# INF 2
# INF 0
#
# INF
# INF a
# INF 0
# INF 70
# INF 72
# INF 0
# INF 71
#
# Klinikum Bergheim
#
# 17
# Familientherapie
# 18
# Frauenklinik
# 20  Arbeits-,Sozialmedizin
# 21  Med. Psychosomatik
# 22  Hautklinik
# 2  Rechts-,Verkehrsmed.
# 2  Psychiatr ische K linik
# 2  Psychosomatische K linik
# 2  Psychiatr ische K linik
# 27  Pr inzhornsammlung
# 28  K inderpsychiatr ie
#
# Bergheimer Str.
# Voßstr. 9
# V0ßstr. 2
# Bergheimer Str. 20
# Voßstr. 2
# Voßstr. 2
# Voßstr. 2
# Thibautstr. 2
# Voßstr.
# Voßstr. 2
# Blumenstr. 8
#
# 1
#
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
# ===========《第69页》===========
# www.klinikum.uni-heidelberg.de
#
# 1

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
import os 

def convert_pdf_to_txt(path, pages=None):
    if not pages:
        pagenums = set()
    else:
        pagenums = set(pages)
    output = StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    infile = open(path, 'rb')
    for page in PDFPage.get_pages(infile, pagenums):
        interpreter.process_page(page)
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close()
    return text

s = convert_pdf_to_txt(phone_numebrs[0])
print(s)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-faeb9e678a25> in <module>
#       2 from pdfminer.converter import TextConverter
#       3 from pdfminer.layout import LAParams
# ----> 4 from pdfminer.pdfpage import PDFPage
#       5 from io import StringIO
#       6 import os
#
# ModuleNotFoundError: No module named 'pdfminer.pdfpage'

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import HTMLConverter,TextConverter,XMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import io

def convert(case,fname, pages=None):
    if not pages: pagenums = set();
    else:         pagenums = set(pages);      
    manager = PDFResourceManager() 
    codec = 'utf-8'
    caching = True

    if case == 'text' :
        output = io.StringIO()
        converter = TextConverter(manager, output, codec=codec, laparams=LAParams())     
    if case == 'HTML' :
        output = io.BytesIO()
        converter = HTMLConverter(manager, output, codec=codec, laparams=LAParams())

    interpreter = PDFPageInterpreter(manager, converter)   
    infile = open(fname, 'rb')

    for page in PDFPage.get_pages(infile, pagenums,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    convertedPDF = output.getvalue()  

    infile.close(); converter.close(); output.close()
    return convertedPDF

#//////////// main ///////////////////////
filePDF  = './data/phone_numbers/070219_KV_BR_Telefonverzei.pdf'     # input
fileHTML = 'myHTML.html'   # output
fileTXT  = 'myTXT.txt'     # output

case = "text"

if case == 'HTML' :
    convertedPDF = convert('HTML', filePDF)
    fileConverted = open(fileHTML, "wb", encoding="utf-8")
if case == 'text' :
    convertedPDF = convert('text', filePDF)
    fileConverted = open(fileTXT, "w", encoding="utf-8")

fileConverted.write(convertedPDF)
fileConverted.close()
#print(convertedPDF)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-fd11c5bb53b0> in <module>
#       2 from pdfminer.converter import HTMLConverter,TextConverter,XMLConverter
#       3 from pdfminer.layout import LAParams
# ----> 4 from pdfminer.pdfpage import PDFPage
#       5 import io
#       6
#
# ModuleNotFoundError: No module named 'pdfminer.pdfpage'

# %% [markdown]
# ### pdftotree
#
# pyocr

# %%
# import pdftotree
import subprocess
import pyocr
import importlib
import sys,os
import time
import requests

importlib.reload(sys)
time1 = time.time()



def pdf_to_html(pdf_path):
    """
    将pdf转HTML，成功与不成功的
    :param pdf_path: pdf的本地路径
    :return:如果该文件是扫描版，返回扫描版，如果转换失败返回False,如果成功返回转化成HTML的地址
    """
    try:
        pdf_file = pdf_path
        html_output = pdf_file.split(".")[0]+".html"
        html_output_path = html_output.split("/")[-1]
        cmd = 'pdftotree' + " " + "-o" + " " + html_output + " " + pdf_file
        b = run_command(cmd.split())
        for i in b:
            i = i.decode()
            if "cannot build tree structure" in i:
                raise Exception("该文件是PDF扫描版")
            if "tabula.errors.JavaNotFoundError" in i:
                raise Exception(
                    "tabula.errors.JavaNotFoundError: `java` command is not found from this Python process. "
                    "Please ensure Java is installed and PATH is set for `java`")
            info(f"{pdf_file}已经转换成HTML")
            html_output_path = html_output_path+html_output_path
            domain_url = "/Users/gongsi/PycharmProjects/sticker/formal/AIQT_DATA/citic_report/citic_report/down_pdf/"
            file_path = os.path.join(os.path.dirname(__file__),)
            print(">>>>file",file_path)
            if os.path.exists(domain_url+html_output_path):

                return html_output_path
            return False
    except Exception as e:
        print('出现错误了', e)
        if "PDF扫描版" in e:
            return "PDF扫描版"
        return False
    
def run_command(command):
    """
    执行cmd命令
    :param command: cmd字符串
    :return: 包含执行命令结果的一个迭代器
    """
    p = subprocess.Popen(command,
                         stdout=subprocess.PIPE,
                         stderr=subprocess.STDOUT)
    return iter(p.stdout.readline, b'')

pdf_to_html("./ITA_asg_1.pdf")
# Out:
# 出现错误了 [WinError 2] The system cannot find the file specified
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b588c8691968> in pdf_to_html(pdf_path)
#      24         cmd = 'pdftotree' + " " + "-o" + " " + html_output + " " + pdf_file
# ---> 25         b = run_command(cmd.split())
#      26         for i in b:
#
# <ipython-input-4-b588c8691968> in run_command(command)
#      54     """
# ---> 55     p = subprocess.Popen(command,
#      56                          stdout=subprocess.PIPE,
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1306             try:
# -> 1307                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1308                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b588c8691968> in <module>
#      58     return iter(p.stdout.readline, b'')
#      59
# ---> 60 pdf_to_html("./ITA_asg_1.pdf")
#
# <ipython-input-4-b588c8691968> in pdf_to_html(pdf_path)
#      43     except Exception as e:
#      44         print('出现错误了', e)
# ---> 45         if "PDF扫描版" in e:
#      46             return "PDF扫描版"
#      47         return False
#
# TypeError: argument of type 'FileNotFoundError' is not iterable

# %% [markdown]
# ### PDF TO Text

# %%
import pdftotext

 # Load your PDF
with open("./data/phone_numbers/070219_KV_BR_Telefonverzei.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

 # Save all text to a txt file.
with open('test.txt', 'w') as f:
    f.write("\n\n".join(pdf))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f3aa65cd7aa9> in <module>
# ----> 1 import pdftotext
#       2
#       3  # Load your PDF
#       4 with open("./data/phone_numbers/070219_KV_BR_Telefonverzei.pdf", "rb") as f:
#       5     pdf = pdftotext.PDF(f)
#
# ModuleNotFoundError: No module named 'pdftotext'
